# %% [markdown]
# # BindCraft: Protein binder design
#
# <img src="https://github.com/martinpacesa/BindCraft/blob/main/pipeline.png?raw=true">
#
# Simple binder design pipeline using AlphaFold2 backpropagation, MPNN, and PyRosetta. Select your target and let the script do the rest of the work and finish once you have enough designs to order!
#
# The designs will be saved on your Google Drive under BindCraft/[design_name]/ and you can continue running the design pipeline if the session times out and it will continue adding new designs.

# %%
#@title Installation
# %%time
import os, time, gc, io
import contextlib
import json
from datetime import datetime
from ipywidgets import HTML, VBox
from IPython.display import display

if not os.path.isfile("bindcraft/params/done.txt"):
  print("Installing required BindCraft components")

  print("Pulling BindCraft code from Github")
  os.makedirs('/content/bindcraft/', exist_ok=True)
  # !git clone https://github.com/martinpacesa/BindCraft /content/bindcraft/
  os.system("chmod +x /content/bindcraft/functions/dssp")
  os.system("chmod +x /content/bindcraft/functions/DAlphaBall.gcc")

  print("Installing ColabDesign")
  os.system("(mkdir bindcraft/params; apt-get install aria2 -qq; \
  aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar; \
  tar -xf alphafold_params_2022-12-06.tar -C bindcraft/params; touch bindcraft/params/done.txt )&")
  os.system("pip install git+https://github.com/sokrypton/ColabDesign.git")
  # for debugging purposes
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")

  print("Installing PyRosetta")
  # !pip install -q pyrosetta --find-links https://west.rosettacommons.org/pyrosetta/quarterly/release.cxx11thread.serialization

  # download params
  if not os.path.isfile("bindcraft/params/done.txt"):
    print("downloading AlphaFold params")
    while not os.path.isfile("bindcraft/params/done.txt"):
      time.sleep(5)

  print("BindCraft installation is finished, ready to run!")
else:
  print("BindCraft components already installed, ready to run!")
# Out:
# Installing required BindCraft components
# Pulling BindCraft code from Github
# Cloning into '/content/bindcraft'...
# remote: Enumerating objects: 457, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 457 (delta 198), reused 161 (delta 161), pack-reused 240 (from 2)
# Receiving objects: 100% (457/457), 5.68 MiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (288/288), done.
# Installing ColabDesign
# Installing PyRosetta
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 GB 1.2 MB/s eta 0:00:00
# BindCraft installation is finished, ready to run!
# CPU times: user 2.24 s, sys: 752 ms, total: 2.99 s
# Wall time: 2min 52s

# %%
#@title Mount your Google Drive to save design results
from google.colab import drive
drive.mount('/content/drive')
currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Google drive mounted at: {currenttime}")

bindcraft_google_drive = '/content/drive/My Drive/BindCraft/'
os.makedirs(bindcraft_google_drive, exist_ok=True)
print("BindCraft folder successfully created in your drive!")
# Out:
# Mounted at /content/drive
# Google drive mounted at: 2026-07-12 07:03:23
# BindCraft folder successfully created in your drive!

# %%
#@title Binder design settings
# @markdown ---
# @markdown Enter path where to save your designs. We recommend to save on Google drive so that you can continue generating at any time.
design_path = "/content/drive/MyDrive/BindCraft/" # @param {"type":"string","placeholder":"/content/drive/MyDrive/BindCraft/PDL1/"}

# @markdown Enter the name that should be prefixed to your binders (generally target name).
binder_name = "PEDV_CTD_binder" # @param {"type":"string","placeholder":"PDL1"}

# @markdown The path to the .pdb structure of your target. Can be an experimental or AlphaFold2 structure. We recommend trimming the structure to as small as needed, as the whole selected chains will be backpropagated through the network and can significantly increase running times.
starting_pdb = "/content/drive/MyDrive/BindCraft/7Y6U_S1_CTD_extended.pdb" # @param {"type":"string","placeholder":"/content/bindcraft/example/PDL1.pdb"}

# @markdown Which chains of your PDB to target? Can be one or multiple, in a comma-separated format. Other chains will be ignored during design.
chains = "A" # @param {"type":"string","placeholder":"A,C"}

# @markdown What positions to target in your protein of interest? For example `1,2-10` or chain specific `A1-10,B1-20` or entire chains `A`. If left blank, an appropriate site will be selected by the pipeline.
target_hotspot_residues = "" # @param {"type":"string","placeholder":""}

# @markdown What is the minimum and maximum size of binders you want to design? Pipeline will randomly sample different sizes between these values.
lengths = "60,140" # @param {"type":"string","placeholder":"70,150"}

# @markdown How many binder designs passing filters do you require?
number_of_final_designs = 20 # @param {"type":"integer","placeholder":"100"}
# @markdown ---
# @markdown Enter path on your Google drive (/content/drive/MyDrive/BindCraft/[binder_name].json) to previous target settings to continue design campaign. If left empty, it will use the settings above and generate a new settings json in your design output folder.
load_previous_target_settings = "" # @param {"type":"string","placeholder":""}
# @markdown ---

if load_previous_target_settings:
    target_settings_path = load_previous_target_settings
else:
    lengths = [int(x.strip()) for x in lengths.split(',') if len(lengths.split(',')) == 2]

    if len(lengths) != 2:
        raise ValueError("Incorrect specification of binder lengths.")

    settings = {
        "design_path": design_path,
        "binder_name": binder_name,
        "starting_pdb": starting_pdb,
        "chains": chains,
        "target_hotspot_residues": target_hotspot_residues,
        "lengths": lengths,
        "number_of_final_designs": number_of_final_designs
    }

    target_settings_path = os.path.join(design_path, binder_name+".json")
    os.makedirs(design_path, exist_ok=True)

    with open(target_settings_path, 'w') as f:
        json.dump(settings, f, indent=4)

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Binder design settings updated at: {currenttime}")
print(f"New .json file with target settings has been generated in: {target_settings_path}")
# Out:
# Binder design settings updated at: 2026-07-12 07:03:42
# New .json file with target settings has been generated in: /content/drive/MyDrive/BindCraft/PEDV_CTD_binder.json

# %%
#@title Advanced settings
# @markdown ---
# @markdown Which binder design protocol to run? Default is recommended. "Beta-sheet" promotes the design of more beta sheeted proteins, but requires more sampling. "Peptide" is optimised for helical peptide binders.
design_protocol = "Default" # @param ["Default","Beta-sheet","Peptide"]
# @markdown What prediction protocol to use?. "Default" performs single sequence prediction of the binder. "HardTarget" uses initial guess to improve complex prediction for difficult targets, but might introduce some bias.
prediction_protocol = "Default" # @param ["Default","HardTarget"]
# @markdown What interface design method to use?. "AlphaFold2" is the default, interface is generated by AlphaFold2. "MPNN" uses soluble MPNN to optimise the interface.
interface_protocol = "AlphaFold2" # @param ["AlphaFold2","MPNN"]
# @markdown What target template protocol to use? "Default" allows for limited amount flexibility. "Masked" allows for greater target flexibility on both sidechain and backbone level.
template_protocol = "Default" # @param ["Default","Masked"]
# @markdown ---

if design_protocol == "Default":
    design_protocol_tag = "default_4stage_multimer"
elif design_protocol == "Beta-sheet":
    design_protocol_tag = "betasheet_4stage_multimer"
elif design_protocol == "Peptide":
    design_protocol_tag = "peptide_3stage_multimer"
else:
    raise ValueError(f"Unsupported design protocol")

if interface_protocol == "AlphaFold2":
    interface_protocol_tag = ""
elif interface_protocol == "MPNN":
    interface_protocol_tag = "_mpnn"
else:
    raise ValueError(f"Unsupported interface protocol")

if template_protocol == "Default":
    template_protocol_tag = ""
elif template_protocol == "Masked":
    template_protocol_tag = "_flexible"
else:
    raise ValueError(f"Unsupported template protocol")

if design_protocol in ["Peptide"]:
    prediction_protocol_tag = ""
else:
    if prediction_protocol == "Default":
        prediction_protocol_tag = ""
    elif prediction_protocol == "HardTarget":
        prediction_protocol_tag = "_hardtarget"
    else:
        raise ValueError(f"Unsupported prediction protocol")

advanced_settings_path = "/content/bindcraft/settings_advanced/" + design_protocol_tag + interface_protocol_tag + template_protocol_tag + prediction_protocol_tag + ".json"

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Advanced design settings updated at: {currenttime}")
# Out:
# Advanced design settings updated at: 2026-07-12 07:03:47

# %%
#@title Filters
# @markdown ---
# @markdown Which filters for designs to use? "Default" are recommended, "Peptide" are for the design of peptide binders, "Relaxed" are more permissive but may result in fewer experimental successes, "Peptide_Relaxed" are more permissive filters for non-helical peptides, "None" is for benchmarking.
filter_option = "Default" # @param ["Default", "Peptide", "Relaxed", "Peptide_Relaxed", "None"]
# @markdown ---

if filter_option == "Default":
    filter_settings_path = "/content/bindcraft/settings_filters/default_filters.json"
elif filter_option == "Peptide":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_filters.json"
elif filter_option == "Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/relaxed_filters.json"
elif filter_option == "Peptide_Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_relaxed_filters.json"
elif filter_option == "None":
    filter_settings_path = "/content/bindcraft/settings_filters/no_filters.json"
else:
    raise ValueError(f"Unsupported filter type")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Filter settings updated at: {currenttime}")
# Out:
# Filter settings updated at: 2026-07-12 07:03:50

# %% [markdown]
# # Everything is set, BindCraft is ready to run!

# %%
# @title Import functions and settings
from bindcraft.functions import *

args = {"settings":target_settings_path,
        "filters":filter_settings_path,
        "advanced":advanced_settings_path}

# Check if JAX-capable GPU is available, otherwise exit
check_jax_gpu()

# perform checks of input setting files
settings_path, filters_path, advanced_path = (args["settings"], args["filters"], args["advanced"])

### load settings from JSON
target_settings, advanced_settings, filters = load_json_settings(settings_path, filters_path, advanced_path)

settings_file = os.path.basename(settings_path).split('.')[0]
filters_file = os.path.basename(filters_path).split('.')[0]
advanced_file = os.path.basename(advanced_path).split('.')[0]

### load AF2 model settings
design_models, prediction_models, multimer_validation = load_af2_models(advanced_settings["use_multimer_design"])

### perform checks on advanced_settings
bindcraft_folder = "colab"
advanced_settings = perform_advanced_settings_check(advanced_settings, bindcraft_folder)

### generate directories, design path names can be found within the function
design_paths = generate_directories(target_settings["design_path"])

### generate dataframes
trajectory_labels, design_labels, final_labels = generate_dataframe_labels()

trajectory_csv = os.path.join(target_settings["design_path"], 'trajectory_stats.csv')
mpnn_csv = os.path.join(target_settings["design_path"], 'mpnn_design_stats.csv')
final_csv = os.path.join(target_settings["design_path"], 'final_design_stats.csv')
failure_csv = os.path.join(target_settings["design_path"], 'failure_csv.csv')

create_dataframe(trajectory_csv, trajectory_labels)
create_dataframe(mpnn_csv, design_labels)
create_dataframe(final_csv, final_labels)
generate_filter_pass_csv(failure_csv, args["filters"])

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Loaded design functions and settings at: {currenttime}")
# Out:
# Available GPUs:
# NVIDIA A100-SXM4-80GB1: gpu
# Loaded design functions and settings at: 2026-07-12 07:04:01

# %%
#@title Initialise PyRosetta

####################################
####################################
####################################
### initialise PyRosetta
pr.init(f'-ignore_unrecognized_res -ignore_zero_occupancy -mute all -holes:dalphaball {advanced_settings["dalphaball_path"]} -corrections::beta_nov16 true -relax:default_repeats 1')
# Out:
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.Release.python312.ubuntu.cxx11thread.serialization 2026.03+releasequarterly.5e498f1409c68ade56c8ce5842bf79e1b02e8db4 2026-01-13T13:24:11] retrieved from: http://www.pyrosetta.org

# %%
#@title Run BindCraft!
####################################
###################### BindCraft Run
####################################
# Colab-specific: live displays
num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
num_accepted_designs = len(pd.read_csv(final_csv))
sampled_trajectories_label = HTML(value=f"<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>{num_sampled_trajectories}</span></h3>")
accepted_designs_label = HTML(value=f"<h3 style='color: #2ca02c;'>Accepted Designs: <span style='color: #2ca02c;'>{num_accepted_designs}</span></h3>")
display(VBox([sampled_trajectories_label, accepted_designs_label]))

# initialise counters
script_start_time = time.time()
trajectory_n = 1
accepted_designs = 0

### start design loop
while True:
    ### check if we have the target number of binders
    final_designs_reached = check_accepted_designs(design_paths, mpnn_csv, final_labels, final_csv, advanced_settings, target_settings, design_labels)

    if final_designs_reached:
        # stop design loop execution
        break

    ### check if we reached maximum allowed trajectories
    max_trajectories_reached = check_n_trajectories(design_paths, advanced_settings)

    if max_trajectories_reached:
        break

    ### Initialise design
    # measure time to generate design
    trajectory_start_time = time.time()

    # generate random seed to vary designs
    seed = int(np.random.randint(0, high=999999, size=1, dtype=int)[0])

    # sample binder design length randomly from defined distribution
    samples = np.arange(min(target_settings["lengths"]), max(target_settings["lengths"]) + 1)
    length = np.random.choice(samples)

    # load desired helicity value to sample different secondary structure contents
    helicity_value = load_helicity(advanced_settings)

    # generate design name and check if same trajectory was already run
    design_name = target_settings["binder_name"] + "_l" + str(length) + "_s"+ str(seed)
    trajectory_dirs = ["Trajectory", "Trajectory/Relaxed", "Trajectory/LowConfidence", "Trajectory/Clashing"]
    trajectory_exists = any(os.path.exists(os.path.join(design_paths[trajectory_dir], design_name + ".pdb")) for trajectory_dir in trajectory_dirs)

    if not trajectory_exists:
        print("Starting trajectory: "+design_name)

        ### Begin binder hallucination
        trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
                                            target_settings["target_hotspot_residues"], length, seed, helicity_value,
                                            design_models, advanced_settings, design_paths, failure_csv)
        trajectory_metrics = copy_dict(trajectory._tmp["best"]["aux"]["log"]) # contains plddt, ptm, i_ptm, pae, i_pae
        trajectory_pdb = os.path.join(design_paths["Trajectory"], design_name + ".pdb")

        # round the metrics to two decimal places
        trajectory_metrics = {k: round(v, 2) if isinstance(v, float) else v for k, v in trajectory_metrics.items()}

        # time trajectory
        trajectory_time = time.time() - trajectory_start_time
        trajectory_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(trajectory_time // 3600), int((trajectory_time % 3600) // 60), int(trajectory_time % 60))}"
        print("Starting trajectory took: "+trajectory_time_text)
        print("")

        # Proceed if there is no trajectory termination signal
        if trajectory.aux["log"]["terminate"] == "":
            # Relax binder to calculate statistics
            trajectory_relaxed = os.path.join(design_paths["Trajectory/Relaxed"], design_name + ".pdb")
            pr_relax(trajectory_pdb, trajectory_relaxed)

            # define binder chain, placeholder in case multi-chain parsing in ColabDesign gets changed
            binder_chain = "B"

            # Calculate clashes before and after relaxation
            num_clashes_trajectory = calculate_clash_score(trajectory_pdb)
            num_clashes_relaxed = calculate_clash_score(trajectory_relaxed)

            # secondary structure content of starting trajectory binder and interface
            trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_i_plddt, trajectory_ss_plddt = calc_ss_percentage(trajectory_pdb, advanced_settings, binder_chain)

            # analyze interface scores for relaxed af2 trajectory
            trajectory_interface_scores, trajectory_interface_AA, trajectory_interface_residues = score_interface(trajectory_relaxed, binder_chain)

            # starting binder sequence
            trajectory_sequence = trajectory.get_seq(get_best=True)[0]

            # analyze sequence
            traj_seq_notes = validate_design_sequence(trajectory_sequence, num_clashes_relaxed, advanced_settings)

            # target structure RMSD compared to input PDB
            trajectory_target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], trajectory_pdb, target_settings["chains"], 'A')

            # save trajectory statistics into CSV
            trajectory_data = [design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], trajectory_sequence, trajectory_interface_residues,
                                trajectory_metrics['plddt'], trajectory_metrics['ptm'], trajectory_metrics['i_ptm'], trajectory_metrics['pae'], trajectory_metrics['i_pae'],
                                trajectory_i_plddt, trajectory_ss_plddt, num_clashes_trajectory, num_clashes_relaxed, trajectory_interface_scores['binder_score'],
                                trajectory_interface_scores['surface_hydrophobicity'], trajectory_interface_scores['interface_sc'], trajectory_interface_scores['interface_packstat'],
                                trajectory_interface_scores['interface_dG'], trajectory_interface_scores['interface_dSASA'], trajectory_interface_scores['interface_dG_SASA_ratio'],
                                trajectory_interface_scores['interface_fraction'], trajectory_interface_scores['interface_hydrophobicity'], trajectory_interface_scores['interface_nres'], trajectory_interface_scores['interface_interface_hbonds'],
                                trajectory_interface_scores['interface_hbond_percentage'], trajectory_interface_scores['interface_delta_unsat_hbonds'], trajectory_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_interface_AA, trajectory_target_rmsd,
                                trajectory_time_text, traj_seq_notes, settings_file, filters_file, advanced_file]
            insert_data(trajectory_csv, trajectory_data)

            if advanced_settings["enable_mpnn"]:
                # initialise MPNN counters
                mpnn_n = 1
                accepted_mpnn = 0
                mpnn_dict = {}
                design_start_time = time.time()

                ### MPNN redesign of starting binder
                mpnn_trajectories = mpnn_gen_sequence(trajectory_pdb, binder_chain, trajectory_interface_residues, advanced_settings)
                existing_mpnn_sequences = set(pd.read_csv(mpnn_csv, usecols=['Sequence'])['Sequence'].values)

                # create set of MPNN sequences with allowed amino acid composition
                restricted_AAs = set(aa.strip().upper() for aa in advanced_settings["omit_AAs"].split(',')) if advanced_settings["force_reject_AA"] else set()

                mpnn_sequences = sorted({
                    mpnn_trajectories['seq'][n][-length:]: {
                        'seq': mpnn_trajectories['seq'][n][-length:],
                        'score': mpnn_trajectories['score'][n],
                        'seqid': mpnn_trajectories['seqid'][n]
                    } for n in range(advanced_settings["num_seqs"])
                    if (not restricted_AAs or not any(aa in mpnn_trajectories['seq'][n][-length:].upper() for aa in restricted_AAs))
                    and mpnn_trajectories['seq'][n][-length:] not in existing_mpnn_sequences
                }.values(), key=lambda x: x['score'])

                del existing_mpnn_sequences

                # check whether any sequences are left after amino acid rejection and duplication check, and if yes proceed with prediction
                if mpnn_sequences:
                    # add optimisation for increasing recycles if trajectory is beta sheeted
                    if advanced_settings["optimise_beta"] and float(trajectory_beta) > 15:
                        advanced_settings["num_recycles_validation"] = advanced_settings["optimise_beta_recycles_valid"]

                    ### Compile prediction models once for faster prediction of MPNN sequences
                    clear_mem()
                    # compile complex prediction model
                    complex_prediction_model = mk_afdesign_model(protocol="binder", num_recycles=advanced_settings["num_recycles_validation"], data_dir=advanced_settings["af_params_dir"],
                                                                use_multimer=multimer_validation)
                    complex_prediction_model.prep_inputs(pdb_filename=target_settings["starting_pdb"], chain=target_settings["chains"], binder_len=length, rm_target_seq=advanced_settings["rm_template_seq_predict"],
                                                        rm_target_sc=advanced_settings["rm_template_sc_predict"])

                    # compile binder monomer prediction model
                    binder_prediction_model = mk_afdesign_model(protocol="hallucination", use_templates=False, initial_guess=False,
                                                                use_initial_atom_pos=False, num_recycles=advanced_settings["num_recycles_validation"],
                                                                data_dir=advanced_settings["af_params_dir"], use_multimer=multimer_validation)
                    binder_prediction_model.prep_inputs(length=length)

                    # iterate over designed sequences
                    for mpnn_sequence in mpnn_sequences:
                        mpnn_time = time.time()

                        # generate mpnn design name numbering
                        mpnn_design_name = design_name + "_mpnn" + str(mpnn_n)
                        mpnn_score = round(mpnn_sequence['score'],2)
                        mpnn_seqid = round(mpnn_sequence['seqid'],2)

                        # add design to dictionary
                        mpnn_dict[mpnn_design_name] = {'seq': mpnn_sequence['seq'], 'score': mpnn_score, 'seqid': mpnn_seqid}

                        # save fasta sequence
                        if advanced_settings["save_mpnn_fasta"] is True:
                            save_fasta(mpnn_design_name, mpnn_sequence['seq'], design_paths)

                        ### Predict mpnn redesigned binder complex using masked templates
                        mpnn_complex_statistics, pass_af2_filters = predict_binder_complex(complex_prediction_model,
                                                                                        mpnn_sequence['seq'], mpnn_design_name,
                                                                                        target_settings["starting_pdb"], target_settings["chains"],
                                                                                        length, trajectory_pdb, prediction_models, advanced_settings,
                                                                                        filters, design_paths, failure_csv)

                        # if AF2 filters are not passed then skip the scoring
                        if not pass_af2_filters:
                            print(f"Base AF2 filters not passed for {mpnn_design_name}, skipping interface scoring")
                            mpnn_n += 1
                            continue

                        # calculate statistics for each model individually
                        for model_num in prediction_models:
                            mpnn_design_pdb = os.path.join(design_paths["MPNN"], f"{mpnn_design_name}_model{model_num+1}.pdb")
                            mpnn_design_relaxed = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_design_pdb):
                                # Calculate clashes before and after relaxation
                                num_clashes_mpnn = calculate_clash_score(mpnn_design_pdb)
                                num_clashes_mpnn_relaxed = calculate_clash_score(mpnn_design_relaxed)

                                # analyze interface scores for relaxed af2 trajectory
                                mpnn_interface_scores, mpnn_interface_AA, mpnn_interface_residues = score_interface(mpnn_design_relaxed, binder_chain)

                                # secondary structure content of starting trajectory binder
                                mpnn_alpha, mpnn_beta, mpnn_loops, mpnn_alpha_interface, mpnn_beta_interface, mpnn_loops_interface, mpnn_i_plddt, mpnn_ss_plddt = calc_ss_percentage(mpnn_design_pdb, advanced_settings, binder_chain)

                                # unaligned RMSD calculate to determine if binder is in the designed binding site
                                rmsd_site = unaligned_rmsd(trajectory_pdb, mpnn_design_pdb, binder_chain, binder_chain)

                                # calculate RMSD of target compared to input PDB
                                target_rmsd = target_pdb_rmsd(mpnn_design_pdb, target_settings["starting_pdb"], target_settings["chains"])

                                # add the additional statistics to the mpnn_complex_statistics dictionary
                                mpnn_complex_statistics[model_num+1].update({
                                    'i_pLDDT': mpnn_i_plddt,
                                    'ss_pLDDT': mpnn_ss_plddt,
                                    'Unrelaxed_Clashes': num_clashes_mpnn,
                                    'Relaxed_Clashes': num_clashes_mpnn_relaxed,
                                    'Binder_Energy_Score': mpnn_interface_scores['binder_score'],
                                    'Surface_Hydrophobicity': mpnn_interface_scores['surface_hydrophobicity'],
                                    'ShapeComplementarity': mpnn_interface_scores['interface_sc'],
                                    'PackStat': mpnn_interface_scores['interface_packstat'],
                                    'dG': mpnn_interface_scores['interface_dG'],
                                    'dSASA': mpnn_interface_scores['interface_dSASA'],
                                    'dG/dSASA': mpnn_interface_scores['interface_dG_SASA_ratio'],
                                    'Interface_SASA_%': mpnn_interface_scores['interface_fraction'],
                                    'Interface_Hydrophobicity': mpnn_interface_scores['interface_hydrophobicity'],
                                    'n_InterfaceResidues': mpnn_interface_scores['interface_nres'],
                                    'n_InterfaceHbonds': mpnn_interface_scores['interface_interface_hbonds'],
                                    'InterfaceHbondsPercentage': mpnn_interface_scores['interface_hbond_percentage'],
                                    'n_InterfaceUnsatHbonds': mpnn_interface_scores['interface_delta_unsat_hbonds'],
                                    'InterfaceUnsatHbondsPercentage': mpnn_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                    'InterfaceAAs': mpnn_interface_AA,
                                    'Interface_Helix%': mpnn_alpha_interface,
                                    'Interface_BetaSheet%': mpnn_beta_interface,
                                    'Interface_Loop%': mpnn_loops_interface,
                                    'Binder_Helix%': mpnn_alpha,
                                    'Binder_BetaSheet%': mpnn_beta,
                                    'Binder_Loop%': mpnn_loops,
                                    'Hotspot_RMSD': rmsd_site,
                                    'Target_RMSD': target_rmsd
                                })

                                # save space by removing unrelaxed predicted mpnn complex pdb?
                                if advanced_settings["remove_unrelaxed_complex"]:
                                    os.remove(mpnn_design_pdb)

                        # calculate complex averages
                        mpnn_complex_averages = calculate_averages(mpnn_complex_statistics, handle_aa=True)

                        ### Predict binder alone in single sequence mode
                        binder_statistics = predict_binder_alone(binder_prediction_model, mpnn_sequence['seq'], mpnn_design_name, length,
                                                                trajectory_pdb, binder_chain, prediction_models, advanced_settings, design_paths)

                        # extract RMSDs of binder to the original trajectory
                        for model_num in prediction_models:
                            mpnn_binder_pdb = os.path.join(design_paths["MPNN/Binder"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_binder_pdb):
                                rmsd_binder = unaligned_rmsd(trajectory_pdb, mpnn_binder_pdb, binder_chain, "A")

                            # append to statistics
                            binder_statistics[model_num+1].update({
                                    'Binder_RMSD': rmsd_binder
                                })

                            # save space by removing binder monomer models?
                            if advanced_settings["remove_binder_monomer"]:
                                os.remove(mpnn_binder_pdb)

                        # calculate binder averages
                        binder_averages = calculate_averages(binder_statistics)

                        # analyze sequence to make sure there are no cysteins and it contains residues that absorb UV for detection
                        seq_notes = validate_design_sequence(mpnn_sequence['seq'], mpnn_complex_averages.get('Relaxed_Clashes', None), advanced_settings)

                        # measure time to generate design
                        mpnn_end_time = time.time() - mpnn_time
                        elapsed_mpnn_text = f"{'%d hours, %d minutes, %d seconds' % (int(mpnn_end_time // 3600), int((mpnn_end_time % 3600) // 60), int(mpnn_end_time % 60))}"


                        # Insert statistics about MPNN design into CSV, will return None if corresponding model does note exist
                        model_numbers = range(1, 6)
                        statistics_labels = ['pLDDT', 'pTM', 'i_pTM', 'pAE', 'i_pAE', 'i_pLDDT', 'ss_pLDDT', 'Unrelaxed_Clashes', 'Relaxed_Clashes', 'Binder_Energy_Score', 'Surface_Hydrophobicity',
                                            'ShapeComplementarity', 'PackStat', 'dG', 'dSASA', 'dG/dSASA', 'Interface_SASA_%', 'Interface_Hydrophobicity', 'n_InterfaceResidues', 'n_InterfaceHbonds', 'InterfaceHbondsPercentage',
                                            'n_InterfaceUnsatHbonds', 'InterfaceUnsatHbondsPercentage', 'Interface_Helix%', 'Interface_BetaSheet%', 'Interface_Loop%', 'Binder_Helix%',
                                            'Binder_BetaSheet%', 'Binder_Loop%', 'InterfaceAAs', 'Hotspot_RMSD', 'Target_RMSD']

                        # Initialize mpnn_data with the non-statistical data
                        mpnn_data = [mpnn_design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], mpnn_sequence['seq'], mpnn_interface_residues, mpnn_score, mpnn_seqid]

                        # Add the statistical data for mpnn_complex
                        for label in statistics_labels:
                            mpnn_data.append(mpnn_complex_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(mpnn_complex_statistics.get(model, {}).get(label, None))

                        # Add the statistical data for binder
                        for label in ['pLDDT', 'pTM', 'pAE', 'Binder_RMSD']:  # These are the labels for binder alone
                            mpnn_data.append(binder_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(binder_statistics.get(model, {}).get(label, None))

                        # Add the remaining non-statistical data
                        mpnn_data.extend([elapsed_mpnn_text, seq_notes, settings_file, filters_file, advanced_file])

                        # insert data into csv
                        insert_data(mpnn_csv, mpnn_data)

                        # find best model number by pLDDT
                        plddt_values = {i: mpnn_data[i] for i in range(11, 15) if mpnn_data[i] is not None}

                        # Find the key with the highest value
                        highest_plddt_key = int(max(plddt_values, key=plddt_values.get))

                        # Output the number part of the key
                        best_model_number = highest_plddt_key - 10
                        best_model_pdb = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{best_model_number}.pdb")

                        # run design data against filter thresholds
                        filter_conditions = check_filters(mpnn_data, design_labels, filters)
                        if filter_conditions == True:
                            print(mpnn_design_name+" passed all filters")
                            accepted_mpnn += 1
                            accepted_designs += 1

                            # copy designs to accepted folder
                            shutil.copy(best_model_pdb, design_paths["Accepted"])

                            # insert data into final csv
                            final_data = [''] + mpnn_data
                            insert_data(final_csv, final_data)

                            # copy animation from accepted trajectory
                            if advanced_settings["save_design_animations"]:
                                accepted_animation = os.path.join(design_paths["Accepted/Animation"], f"{design_name}.html")
                                if not os.path.exists(accepted_animation):
                                    shutil.copy(os.path.join(design_paths["Trajectory/Animation"], f"{design_name}.html"), accepted_animation)

                            # copy plots of accepted trajectory
                            plot_files = os.listdir(design_paths["Trajectory/Plots"])
                            plots_to_copy = [f for f in plot_files if f.startswith(design_name) and f.endswith('.png')]
                            for accepted_plot in plots_to_copy:
                                source_plot = os.path.join(design_paths["Trajectory/Plots"], accepted_plot)
                                target_plot = os.path.join(design_paths["Accepted/Plots"], accepted_plot)
                                if not os.path.exists(target_plot):
                                    shutil.copy(source_plot, target_plot)

                        else:
                            print(f"Unmet filter conditions for {mpnn_design_name}")
                            failure_df = pd.read_csv(failure_csv)
                            special_prefixes = ('Average_', '1_', '2_', '3_', '4_', '5_')
                            incremented_columns = set()

                            for column in filter_conditions:
                                base_column = column
                                for prefix in special_prefixes:
                                    if column.startswith(prefix):
                                        base_column = column.split('_', 1)[1]

                                if base_column not in incremented_columns:
                                    failure_df[base_column] = failure_df[base_column] + 1
                                    incremented_columns.add(base_column)

                            failure_df.to_csv(failure_csv, index=False)
                            shutil.copy(best_model_pdb, design_paths["Rejected"])

                        # increase MPNN design number
                        mpnn_n += 1

                        # if enough mpnn sequences of the same trajectory pass filters then stop
                        if accepted_mpnn >= advanced_settings["max_mpnn_sequences"]:
                            break

                    if accepted_mpnn >= 1:
                        print("Found "+str(accepted_mpnn)+" MPNN designs passing filters")
                    else:
                        print("No accepted MPNN designs found for this trajectory.")

                else:
                    print('Duplicate MPNN designs sampled with different trajectory, skipping current trajectory optimisation')

                # save space by removing unrelaxed design trajectory PDB
                if advanced_settings["remove_unrelaxed_trajectory"]:
                    os.remove(trajectory_pdb)

                # measure time it took to generate designs for one trajectory
                design_time = time.time() - design_start_time
                design_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(design_time // 3600), int((design_time % 3600) // 60), int(design_time % 60))}"
                print("Design and validation of trajectory "+design_name+" took: "+design_time_text)

            # analyse the rejection rate of trajectories to see if we need to readjust the design weights
            if trajectory_n >= advanced_settings["start_monitoring"] and advanced_settings["enable_rejection_check"]:
                acceptance = accepted_designs / trajectory_n
                if not acceptance >= advanced_settings["acceptance_rate"]:
                    print("The ratio of successful designs is lower than defined acceptance rate! Consider changing your design settings!")
                    print("Script execution stopping...")
                    break

        # increase trajectory number
        trajectory_n += 1

        # Colab-specific: update counters
        num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
        num_accepted_designs = len(pd.read_csv(final_csv))
        sampled_trajectories_label.value = f"Sampled trajectories: {num_sampled_trajectories}"
        accepted_designs_label.value = f"Accepted designs: {num_accepted_designs}"

### Script finished
elapsed_time = time.time() - script_start_time
elapsed_text = f"{'%d hours, %d minutes, %d seconds' % (int(elapsed_time // 3600), int((elapsed_time % 3600) // 60), int(elapsed_time % 60))}"
print("Finished all designs. Script execution for "+str(trajectory_n)+" trajectories took: "+elapsed_text)
# Out:
# VBox(children=(HTML(value="<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>12<…
# Streaming output truncated to the last 5000 lines.
# 79 models [0] recycles 1 hard 0 soft 1 temp 0.83 loss 6.61 helix 1.21 pae 0.65 i_pae 0.84 con 2.07 i_con 4.57 plddt 0.66 ptm 0.53 i_ptm 0.12 rg -0.30
# 80 models [1] recycles 1 hard 0 soft 1 temp 0.79 loss 6.41 helix 1.27 pae 0.63 i_pae 0.87 con 1.55 i_con 4.88 plddt 0.78 ptm 0.55 i_ptm 0.10 rg -0.15
# 81 models [2] recycles 1 hard 0 soft 1 temp 0.75 loss 5.85 helix 1.39 pae 0.60 i_pae 0.82 con 1.48 i_con 4.42 plddt 0.82 ptm 0.52 i_ptm 0.14 rg -0.06
# 82 models [4] recycles 1 hard 0 soft 1 temp 0.72 loss 5.92 helix 1.39 pae 0.60 i_pae 0.83 con 1.47 i_con 4.48 plddt 0.79 ptm 0.54 i_ptm 0.13 rg -0.04
# 83 models [2] recycles 1 hard 0 soft 1 temp 0.68 loss 6.08 helix 1.45 pae 0.62 i_pae 0.85 con 1.41 i_con 4.73 plddt 0.83 ptm 0.53 i_ptm 0.12 rg -0.07
# 84 models [2] recycles 1 hard 0 soft 1 temp 0.64 loss 5.94 helix 1.46 pae 0.62 i_pae 0.85 con 1.43 i_con 4.56 plddt 0.84 ptm 0.53 i_ptm 0.12 rg -0.03
# 85 models [3] recycles 1 hard 0 soft 1 temp 0.61 loss 6.05 helix 1.47 pae 0.61 i_pae 0.84 con 1.40 i_con 4.71 plddt 0.83 ptm 0.53 i_ptm 0.11 rg -0.02
# 86 models [2] recycles 1 hard 0 soft 1 temp 0.58 loss 5.84 helix 1.44 pae 0.60 i_pae 0.83 con 1.43 i_con 4.47 plddt 0.83 ptm 0.53 i_ptm 0.14 rg -0.04
# 87 models [3] recycles 1 hard 0 soft 1 temp 0.54 loss 5.75 helix 1.50 pae 0.58 i_pae 0.80 con 1.39 i_con 4.44 plddt 0.83 ptm 0.57 i_ptm 0.15 rg -0.03
# 88 models [4] recycles 1 hard 0 soft 1 temp 0.51 loss 5.99 helix 1.40 pae 0.61 i_pae 0.83 con 1.45 i_con 4.58 plddt 0.80 ptm 0.55 i_ptm 0.12 rg -0.04
# 89 models [2] recycles 1 hard 0 soft 1 temp 0.48 loss 6.02 helix 1.49 pae 0.62 i_pae 0.84 con 1.43 i_con 4.67 plddt 0.82 ptm 0.55 i_ptm 0.12 rg -0.06
# 90 models [1] recycles 1 hard 0 soft 1 temp 0.45 loss 6.35 helix 1.35 pae 0.65 i_pae 0.88 con 1.47 i_con 4.91 plddt 0.80 ptm 0.56 i_ptm 0.09 rg -0.16
# 91 models [1] recycles 1 hard 0 soft 1 temp 0.42 loss 5.95 helix 1.45 pae 0.59 i_pae 0.81 con 1.47 i_con 4.55 plddt 0.83 ptm 0.58 i_ptm 0.15 rg -0.03
# 92 models [0] recycles 1 hard 0 soft 1 temp 0.39 loss 6.24 helix 1.48 pae 0.63 i_pae 0.87 con 1.47 i_con 4.85 plddt 0.80 ptm 0.53 i_ptm 0.09 rg -0.13
# 93 models [1] recycles 1 hard 0 soft 1 temp 0.37 loss 6.14 helix 1.46 pae 0.62 i_pae 0.85 con 1.41 i_con 4.79 plddt 0.83 ptm 0.56 i_ptm 0.10 rg -0.04
# 94 models [4] recycles 1 hard 0 soft 1 temp 0.34 loss 5.27 helix 1.47 pae 0.55 i_pae 0.75 con 1.44 i_con 3.92 plddt 0.82 ptm 0.57 i_ptm 0.25 rg -0.01
# 95 models [3] recycles 1 hard 0 soft 1 temp 0.32 loss 5.87 helix 1.40 pae 0.59 i_pae 0.81 con 1.41 i_con 4.51 plddt 0.85 ptm 0.56 i_ptm 0.14 rg 0.01
# 96 models [1] recycles 1 hard 0 soft 1 temp 0.29 loss 5.20 helix 1.34 pae 0.50 i_pae 0.67 con 1.40 i_con 3.90 plddt 0.84 ptm 0.61 i_ptm 0.27 rg -0.04
# 97 models [2] recycles 1 hard 0 soft 1 temp 0.27 loss 4.97 helix 1.40 pae 0.47 i_pae 0.64 con 1.52 i_con 3.58 plddt 0.85 ptm 0.60 i_ptm 0.35 rg -0.03
# 98 models [3] recycles 1 hard 0 soft 1 temp 0.25 loss 4.09 helix 1.41 pae 0.34 i_pae 0.46 con 1.42 i_con 2.88 plddt 0.89 ptm 0.69 i_ptm 0.59 rg -0.04
# 99 models [4] recycles 1 hard 0 soft 1 temp 0.23 loss 5.80 helix 1.33 pae 0.56 i_pae 0.76 con 1.65 i_con 4.21 plddt 0.77 ptm 0.58 i_ptm 0.17 rg -0.09
# 100 models [2] recycles 1 hard 0 soft 1 temp 0.21 loss 8.08 helix 1.36 pae 0.73 i_pae 0.81 con 3.37 i_con 4.36 plddt 0.38 ptm 0.57 i_ptm 0.16 rg 0.94
# 101 models [2] recycles 1 hard 0 soft 1 temp 0.19 loss 8.65 helix 1.43 pae 0.73 i_pae 0.80 con 3.62 i_con 4.39 plddt 0.36 ptm 0.60 i_ptm 0.17 rg 1.98
# 102 models [1] recycles 1 hard 0 soft 1 temp 0.17 loss 5.31 helix 1.32 pae 0.52 i_pae 0.71 con 1.43 i_con 3.97 plddt 0.85 ptm 0.61 i_ptm 0.24 rg -0.05
# 103 models [1] recycles 1 hard 0 soft 1 temp 0.15 loss 5.53 helix 1.32 pae 0.54 i_pae 0.74 con 1.45 i_con 4.15 plddt 0.83 ptm 0.60 i_ptm 0.21 rg -0.08
# 104 models [2] recycles 1 hard 0 soft 1 temp 0.14 loss 5.31 helix 1.42 pae 0.53 i_pae 0.72 con 1.50 i_con 3.91 plddt 0.85 ptm 0.58 i_ptm 0.25 rg -0.07
# 105 models [1] recycles 1 hard 0 soft 1 temp 0.12 loss 5.68 helix 1.33 pae 0.56 i_pae 0.77 con 1.43 i_con 4.30 plddt 0.82 ptm 0.59 i_ptm 0.18 rg -0.07
# 106 models [1] recycles 1 hard 0 soft 1 temp 0.11 loss 5.90 helix 1.34 pae 0.57 i_pae 0.78 con 1.60 i_con 4.38 plddt 0.79 ptm 0.59 i_ptm 0.17 rg -0.14
# 107 models [0] recycles 1 hard 0 soft 1 temp 0.09 loss 4.49 helix 1.38 pae 0.39 i_pae 0.53 con 1.46 i_con 3.23 plddt 0.85 ptm 0.65 i_ptm 0.50 rg -0.10
# 108 models [1] recycles 1 hard 0 soft 1 temp 0.08 loss 5.41 helix 1.31 pae 0.51 i_pae 0.70 con 1.50 i_con 3.99 plddt 0.83 ptm 0.62 i_ptm 0.24 rg -0.03
# 109 models [3] recycles 1 hard 0 soft 1 temp 0.07 loss 4.61 helix 1.38 pae 0.42 i_pae 0.56 con 1.49 i_con 3.29 plddt 0.87 ptm 0.65 i_ptm 0.46 rg -0.05
# 110 models [1] recycles 1 hard 0 soft 1 temp 0.06 loss 4.75 helix 1.33 pae 0.42 i_pae 0.57 con 1.45 i_con 3.43 plddt 0.85 ptm 0.65 i_ptm 0.43 rg -0.03
# 111 models [3] recycles 1 hard 0 soft 1 temp 0.05 loss 5.06 helix 1.24 pae 0.42 i_pae 0.56 con 1.78 i_con 3.41 plddt 0.83 ptm 0.66 i_ptm 0.45 rg -0.07
# 112 models [1] recycles 1 hard 0 soft 1 temp 0.04 loss 5.36 helix 1.24 pae 0.47 i_pae 0.63 con 1.74 i_con 3.73 plddt 0.80 ptm 0.63 i_ptm 0.34 rg -0.13
# 113 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 4.88 helix 1.34 pae 0.42 i_pae 0.56 con 1.67 i_con 3.36 plddt 0.83 ptm 0.63 i_ptm 0.47 rg -0.05
# 114 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 4.33 helix 1.37 pae 0.36 i_pae 0.49 con 1.47 i_con 3.04 plddt 0.86 ptm 0.67 i_ptm 0.57 rg 0.01
# 115 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 7.90 helix 0.99 pae 0.71 i_pae 0.84 con 3.14 i_con 4.50 plddt 0.44 ptm 0.58 i_ptm 0.14 rg 0.29
# 116 models [1] recycles 1 hard 0 soft 1 temp 0.02 loss 5.09 helix 1.30 pae 0.46 i_pae 0.63 con 1.48 i_con 3.71 plddt 0.85 ptm 0.63 i_ptm 0.32 rg -0.06
# 117 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 4.80 helix 1.35 pae 0.43 i_pae 0.58 con 1.52 i_con 3.42 plddt 0.87 ptm 0.63 i_ptm 0.41 rg -0.01
# 118 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.82 helix 1.14 pae 0.50 i_pae 0.66 con 2.14 i_con 3.74 plddt 0.74 ptm 0.63 i_ptm 0.34 rg -0.16
# 119 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 5.59 helix 1.32 pae 0.56 i_pae 0.76 con 1.53 i_con 4.13 plddt 0.81 ptm 0.58 i_ptm 0.23 rg -0.10
# 120 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 5.16 helix 1.37 pae 0.49 i_pae 0.67 con 1.48 i_con 3.78 plddt 0.82 ptm 0.60 i_ptm 0.33 rg -0.03
# Softmax trajectory pLDDT good, continuing: 0.89
# Stage 3: One-hot Optimisation
# 121 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.09 helix 1.32 pae 0.48 i_pae 0.66 con 1.48 i_con 3.69 plddt 0.79 ptm 0.62 i_ptm 0.32 rg -0.00
# 122 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 5.00 helix 1.33 pae 0.46 i_pae 0.62 con 1.42 i_con 3.69 plddt 0.83 ptm 0.64 i_ptm 0.34 rg -0.01
# 123 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 5.04 helix 1.34 pae 0.44 i_pae 0.58 con 1.73 i_con 3.44 plddt 0.80 ptm 0.63 i_ptm 0.41 rg -0.03
# 124 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 4.75 helix 1.37 pae 0.43 i_pae 0.58 con 1.53 i_con 3.36 plddt 0.83 ptm 0.63 i_ptm 0.41 rg -0.02
# 125 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.44 helix 1.39 pae 0.37 i_pae 0.50 con 1.42 i_con 3.17 plddt 0.84 ptm 0.66 i_ptm 0.52 rg 0.08
# One-hot trajectory pLDDT good, continuing: 0.84
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [2] recycles 1 hard 1 soft 0 temp 1 loss 5.04 helix 1.36 pae 0.48 i_pae 0.65 con 1.52 i_con 3.62 plddt 0.83 ptm 0.60 i_ptm 0.33 rg 0.01
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.43 helix 1.20 pae 0.45 i_pae 0.60 con 1.79 i_con 3.70 plddt 0.78 ptm 0.65 i_ptm 0.35 rg 0.03
# 128 models [0] recycles 1 hard 1 soft 0 temp 1 loss 6.64 helix 1.30 pae 0.63 i_pae 0.85 con 1.83 i_con 4.82 plddt 0.71 ptm 0.55 i_ptm 0.11 rg -0.08
# 129 models [3] recycles 1 hard 1 soft 0 temp 1 loss 6.56 helix 1.18 pae 0.59 i_pae 0.78 con 2.10 i_con 4.42 plddt 0.70 ptm 0.60 i_ptm 0.17 rg 0.03
# 130 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.97 helix 0.88 pae 0.70 i_pae 0.84 con 2.93 i_con 4.61 plddt 0.48 ptm 0.57 i_ptm 0.13 rg 0.76
# 131 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.74 helix 0.99 pae 0.68 i_pae 0.83 con 3.00 i_con 4.59 plddt 0.47 ptm 0.59 i_ptm 0.14 rg -0.03
# 132 models [1] recycles 1 hard 1 soft 0 temp 1 loss 8.21 helix 0.94 pae 0.72 i_pae 0.86 con 3.33 i_con 4.72 plddt 0.42 ptm 0.59 i_ptm 0.12 rg -0.10
# 133 models [1] recycles 1 hard 1 soft 0 temp 1 loss 8.38 helix 1.10 pae 0.71 i_pae 0.81 con 3.39 i_con 4.46 plddt 0.40 ptm 0.60 i_ptm 0.15 rg 1.31
# 134 models [3] recycles 1 hard 1 soft 0 temp 1 loss 8.00 helix 1.02 pae 0.70 i_pae 0.84 con 3.08 i_con 4.68 plddt 0.45 ptm 0.58 i_ptm 0.13 rg 0.26
# 135 models [0] recycles 1 hard 1 soft 0 temp 1 loss 8.42 helix 1.00 pae 0.73 i_pae 0.88 con 3.19 i_con 4.92 plddt 0.43 ptm 0.55 i_ptm 0.10 rg 0.43
# 136 models [0] recycles 1 hard 1 soft 0 temp 1 loss 8.41 helix 1.00 pae 0.72 i_pae 0.88 con 3.14 i_con 4.89 plddt 0.44 ptm 0.55 i_ptm 0.10 rg 0.69
# 137 models [2] recycles 1 hard 1 soft 0 temp 1 loss 8.63 helix 1.04 pae 0.73 i_pae 0.83 con 3.40 i_con 4.58 plddt 0.40 ptm 0.58 i_ptm 0.13 rg 1.62
# 138 models [2] recycles 1 hard 1 soft 0 temp 1 loss 8.52 helix 1.04 pae 0.72 i_pae 0.84 con 3.41 i_con 4.62 plddt 0.41 ptm 0.58 i_ptm 0.13 rg 1.09
# 139 models [3] recycles 1 hard 1 soft 0 temp 1 loss 8.63 helix 1.04 pae 0.72 i_pae 0.84 con 3.42 i_con 4.67 plddt 0.40 ptm 0.59 i_ptm 0.14 rg 1.23
# 140 models [1] recycles 1 hard 1 soft 0 temp 1 loss 8.70 helix 1.09 pae 0.72 i_pae 0.82 con 3.42 i_con 4.54 plddt 0.40 ptm 0.60 i_ptm 0.15 rg 2.01
# Severe clashes detected, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 9 minutes, 10 seconds
#
# Starting trajectory: PEDV_CTD_binder_l110_s525244
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 14.15 helix 1.91 pae 0.90 i_pae 0.94 con 4.71 i_con 4.71 plddt 0.24 ptm 0.54 i_ptm 0.08 rg 15.77
# 2 models [2] recycles 1 hard 0 soft 0.04 temp 1 loss 15.30 helix 1.73 pae 0.90 i_pae 0.93 con 4.87 i_con 4.82 plddt 0.24 ptm 0.52 i_ptm 0.09 rg 18.52
# 3 models [2] recycles 1 hard 0 soft 0.05 temp 1 loss 12.64 helix 1.61 pae 0.85 i_pae 0.87 con 4.80 i_con 4.54 plddt 0.26 ptm 0.54 i_ptm 0.13 rg 10.81
# 4 models [0] recycles 1 hard 0 soft 0.07 temp 1 loss 11.97 helix 1.37 pae 0.86 i_pae 0.91 con 4.53 i_con 4.89 plddt 0.31 ptm 0.53 i_ptm 0.10 rg 8.05
# 5 models [0] recycles 1 hard 0 soft 0.09 temp 1 loss 11.21 helix 1.49 pae 0.83 i_pae 0.87 con 4.48 i_con 4.75 plddt 0.31 ptm 0.54 i_ptm 0.16 rg 6.34
# 6 models [3] recycles 1 hard 0 soft 0.11 temp 1 loss 9.40 helix 1.51 pae 0.79 i_pae 0.84 con 4.29 i_con 4.50 plddt 0.30 ptm 0.56 i_ptm 0.16 rg 1.82
# 7 models [0] recycles 1 hard 0 soft 0.13 temp 1 loss 9.62 helix 1.27 pae 0.80 i_pae 0.85 con 4.23 i_con 4.64 plddt 0.31 ptm 0.55 i_ptm 0.14 rg 2.03
# 8 models [2] recycles 1 hard 0 soft 0.14 temp 1 loss 9.12 helix 1.25 pae 0.79 i_pae 0.87 con 3.99 i_con 4.77 plddt 0.35 ptm 0.51 i_ptm 0.12 rg 0.77
# 9 models [3] recycles 1 hard 0 soft 0.16 temp 1 loss 8.74 helix 1.56 pae 0.77 i_pae 0.85 con 3.77 i_con 4.76 plddt 0.35 ptm 0.54 i_ptm 0.14 rg 0.59
# 10 models [4] recycles 1 hard 0 soft 0.18 temp 1 loss 8.30 helix 1.88 pae 0.77 i_pae 0.87 con 3.63 i_con 4.69 plddt 0.35 ptm 0.53 i_ptm 0.12 rg 0.13
# 11 models [3] recycles 1 hard 0 soft 0.20 temp 1 loss 8.67 helix 1.74 pae 0.75 i_pae 0.84 con 3.58 i_con 4.70 plddt 0.37 ptm 0.55 i_ptm 0.15 rg 1.43
# 12 models [3] recycles 1 hard 0 soft 0.22 temp 1 loss 8.36 helix 1.87 pae 0.74 i_pae 0.87 con 3.40 i_con 4.93 plddt 0.43 ptm 0.53 i_ptm 0.12 rg 0.34
# 13 models [1] recycles 1 hard 0 soft 0.23 temp 1 loss 7.76 helix 2.30 pae 0.71 i_pae 0.86 con 2.93 i_con 4.86 plddt 0.50 ptm 0.53 i_ptm 0.12 rg 0.65
# 14 models [2] recycles 1 hard 0 soft 0.25 temp 1 loss 7.05 helix 2.36 pae 0.67 i_pae 0.81 con 2.85 i_con 4.47 plddt 0.52 ptm 0.50 i_ptm 0.17 rg -0.02
# 15 models [0] recycles 1 hard 0 soft 0.27 temp 1 loss 8.05 helix 2.02 pae 0.73 i_pae 0.84 con 3.37 i_con 4.69 plddt 0.42 ptm 0.53 i_ptm 0.14 rg 0.37
# 16 models [3] recycles 1 hard 0 soft 0.29 temp 1 loss 7.26 helix 2.53 pae 0.70 i_pae 0.85 con 2.83 i_con 4.82 plddt 0.51 ptm 0.53 i_ptm 0.12 rg -0.29
# 17 models [3] recycles 1 hard 0 soft 0.31 temp 1 loss 7.31 helix 2.63 pae 0.70 i_pae 0.85 con 2.79 i_con 4.77 plddt 0.51 ptm 0.53 i_ptm 0.13 rg 0.29
# 18 models [0] recycles 1 hard 0 soft 0.32 temp 1 loss 7.45 helix 2.27 pae 0.69 i_pae 0.83 con 3.00 i_con 4.72 plddt 0.49 ptm 0.52 i_ptm 0.15 rg -0.14
# 19 models [2] recycles 1 hard 0 soft 0.34 temp 1 loss 7.24 helix 2.50 pae 0.68 i_pae 0.82 con 2.95 i_con 4.60 plddt 0.50 ptm 0.53 i_ptm 0.16 rg -0.04
# 20 models [3] recycles 1 hard 0 soft 0.36 temp 1 loss 7.36 helix 2.43 pae 0.68 i_pae 0.83 con 2.89 i_con 4.74 plddt 0.53 ptm 0.53 i_ptm 0.15 rg 0.04
# 21 models [1] recycles 1 hard 0 soft 0.38 temp 1 loss 7.12 helix 2.60 pae 0.66 i_pae 0.84 con 2.64 i_con 4.85 plddt 0.59 ptm 0.54 i_ptm 0.13 rg -0.09
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 6.64 helix 2.78 pae 0.64 i_pae 0.80 con 2.60 i_con 4.42 plddt 0.59 ptm 0.51 i_ptm 0.21 rg 0.13
# 23 models [4] recycles 1 hard 0 soft 0.41 temp 1 loss 6.44 helix 2.88 pae 0.59 i_pae 0.76 con 2.48 i_con 4.37 plddt 0.62 ptm 0.54 i_ptm 0.23 rg 0.25
# 24 models [3] recycles 1 hard 0 soft 0.43 temp 1 loss 6.87 helix 2.81 pae 0.64 i_pae 0.83 con 2.38 i_con 4.88 plddt 0.65 ptm 0.53 i_ptm 0.13 rg 0.08
# 25 models [1] recycles 1 hard 0 soft 0.45 temp 1 loss 7.15 helix 2.42 pae 0.66 i_pae 0.83 con 2.61 i_con 4.90 plddt 0.60 ptm 0.54 i_ptm 0.13 rg -0.22
# 26 models [4] recycles 1 hard 0 soft 0.47 temp 1 loss 6.45 helix 2.79 pae 0.61 i_pae 0.79 con 2.39 i_con 4.50 plddt 0.64 ptm 0.53 i_ptm 0.16 rg -0.06
# 27 models [3] recycles 1 hard 0 soft 0.49 temp 1 loss 6.74 helix 2.83 pae 0.64 i_pae 0.82 con 2.52 i_con 4.66 plddt 0.62 ptm 0.54 i_ptm 0.15 rg -0.03
# 28 models [0] recycles 1 hard 0 soft 0.50 temp 1 loss 6.01 helix 3.26 pae 0.58 i_pae 0.75 con 2.17 i_con 4.42 plddt 0.68 ptm 0.53 i_ptm 0.24 rg 0.08
# 29 models [4] recycles 1 hard 0 soft 0.52 temp 1 loss 6.12 helix 3.03 pae 0.57 i_pae 0.75 con 2.24 i_con 4.37 plddt 0.68 ptm 0.55 i_ptm 0.21 rg 0.16
# 30 models [2] recycles 1 hard 0 soft 0.54 temp 1 loss 5.79 helix 3.47 pae 0.57 i_pae 0.78 con 1.96 i_con 4.41 plddt 0.75 ptm 0.50 i_ptm 0.20 rg 0.32
# 31 models [0] recycles 1 hard 0 soft 0.56 temp 1 loss 6.12 helix 3.59 pae 0.60 i_pae 0.82 con 1.94 i_con 4.78 plddt 0.74 ptm 0.52 i_ptm 0.17 rg 0.29
# 32 models [0] recycles 1 hard 0 soft 0.58 temp 1 loss 6.35 helix 3.16 pae 0.59 i_pae 0.79 con 2.18 i_con 4.65 plddt 0.69 ptm 0.52 i_ptm 0.18 rg 0.26
# 33 models [0] recycles 1 hard 0 soft 0.59 temp 1 loss 5.83 helix 3.54 pae 0.56 i_pae 0.77 con 1.97 i_con 4.50 plddt 0.74 ptm 0.53 i_ptm 0.21 rg 0.19
# 34 models [2] recycles 1 hard 0 soft 0.61 temp 1 loss 5.12 helix 3.58 pae 0.49 i_pae 0.65 con 1.99 i_con 3.81 plddt 0.75 ptm 0.56 i_ptm 0.40 rg 0.24
# 35 models [3] recycles 1 hard 0 soft 0.63 temp 1 loss 5.95 helix 3.17 pae 0.55 i_pae 0.73 con 2.16 i_con 4.33 plddt 0.71 ptm 0.55 i_ptm 0.23 rg 0.17
# 36 models [1] recycles 1 hard 0 soft 0.65 temp 1 loss 6.46 helix 2.96 pae 0.60 i_pae 0.75 con 2.53 i_con 4.38 plddt 0.62 ptm 0.56 i_ptm 0.24 rg 0.18
# 37 models [2] recycles 1 hard 0 soft 0.67 temp 1 loss 5.12 helix 3.53 pae 0.47 i_pae 0.62 con 1.99 i_con 3.80 plddt 0.77 ptm 0.58 i_ptm 0.38 rg 0.27
# 38 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 4.55 helix 3.90 pae 0.40 i_pae 0.53 con 1.85 i_con 3.52 plddt 0.82 ptm 0.62 i_ptm 0.55 rg 0.33
# 39 models [4] recycles 1 hard 0 soft 0.70 temp 1 loss 5.17 helix 3.70 pae 0.51 i_pae 0.70 con 1.87 i_con 4.04 plddt 0.77 ptm 0.53 i_ptm 0.30 rg 0.14
# 40 models [1] recycles 1 hard 0 soft 0.72 temp 1 loss 5.65 helix 3.66 pae 0.53 i_pae 0.72 con 1.99 i_con 4.34 plddt 0.74 ptm 0.55 i_ptm 0.24 rg 0.23
# 41 models [1] recycles 1 hard 0 soft 0.74 temp 1 loss 5.10 helix 3.94 pae 0.50 i_pae 0.67 con 1.88 i_con 4.02 plddt 0.77 ptm 0.56 i_ptm 0.32 rg 0.20
# 42 models [0] recycles 1 hard 0 soft 0.76 temp 1 loss 5.00 helix 3.74 pae 0.46 i_pae 0.61 con 1.86 i_con 3.87 plddt 0.79 ptm 0.59 i_ptm 0.41 rg 0.35
# 43 models [2] recycles 1 hard 0 soft 0.77 temp 1 loss 4.99 helix 3.90 pae 0.49 i_pae 0.68 con 1.81 i_con 3.96 plddt 0.81 ptm 0.52 i_ptm 0.33 rg 0.25
# 44 models [1] recycles 1 hard 0 soft 0.79 temp 1 loss 5.98 helix 3.71 pae 0.58 i_pae 0.81 con 1.88 i_con 4.79 plddt 0.73 ptm 0.52 i_ptm 0.13 rg 0.08
# 45 models [2] recycles 1 hard 0 soft 0.81 temp 1 loss 5.25 helix 3.61 pae 0.49 i_pae 0.67 con 2.03 i_con 3.96 plddt 0.77 ptm 0.54 i_ptm 0.34 rg 0.07
# 46 models [0] recycles 1 hard 0 soft 0.83 temp 1 loss 5.19 helix 3.44 pae 0.48 i_pae 0.64 con 1.94 i_con 3.93 plddt 0.77 ptm 0.58 i_ptm 0.41 rg 0.15
# 47 models [1] recycles 1 hard 0 soft 0.85 temp 1 loss 8.16 helix 2.40 pae 0.73 i_pae 0.80 con 3.67 i_con 4.53 plddt 0.41 ptm 0.55 i_ptm 0.20 rg 0.69
# 48 models [0] recycles 1 hard 0 soft 0.86 temp 1 loss 6.38 helix 2.80 pae 0.57 i_pae 0.76 con 2.34 i_con 4.50 plddt 0.68 ptm 0.54 i_ptm 0.22 rg 0.00
# 49 models [0] recycles 1 hard 0 soft 0.88 temp 1 loss 5.92 helix 3.27 pae 0.56 i_pae 0.77 con 2.00 i_con 4.56 plddt 0.75 ptm 0.53 i_ptm 0.20 rg -0.07
# 50 models [4] recycles 1 hard 0 soft 0.90 temp 1 loss 5.98 helix 3.11 pae 0.57 i_pae 0.76 con 2.14 i_con 4.39 plddt 0.70 ptm 0.54 i_ptm 0.21 rg 0.03
# Initial trajectory pLDDT good, continuing: 0.82
# Beta sheeted trajectory detected, optimising settings
# Stage 1: Additional Logits Optimisation
# 51 models [0] recycles 3 hard 0 soft 0.04 temp 1 loss 6.48 helix 3.30 pae 0.63 i_pae 0.84 con 2.01 i_con 4.90 plddt 0.72 ptm 0.50 i_ptm 0.12 rg 0.51
# 52 models [1] recycles 3 hard 0 soft 0.08 temp 1 loss 5.79 helix 3.28 pae 0.55 i_pae 0.73 con 1.98 i_con 4.38 plddt 0.75 ptm 0.55 i_ptm 0.22 rg 0.20
# 53 models [1] recycles 3 hard 0 soft 0.12 temp 1 loss 5.03 helix 3.67 pae 0.47 i_pae 0.65 con 1.78 i_con 4.01 plddt 0.81 ptm 0.59 i_ptm 0.31 rg 0.11
# 54 models [3] recycles 3 hard 0 soft 0.16 temp 1 loss 4.84 helix 3.44 pae 0.46 i_pae 0.60 con 1.92 i_con 3.63 plddt 0.79 ptm 0.59 i_ptm 0.45 rg 0.09
# 55 models [2] recycles 3 hard 0 soft 0.20 temp 1 loss 5.00 helix 3.23 pae 0.44 i_pae 0.58 con 2.05 i_con 3.62 plddt 0.79 ptm 0.60 i_ptm 0.46 rg 0.04
# 56 models [2] recycles 3 hard 0 soft 0.24 temp 1 loss 4.71 helix 3.74 pae 0.45 i_pae 0.61 con 1.81 i_con 3.74 plddt 0.81 ptm 0.56 i_ptm 0.40 rg 0.01
# 57 models [0] recycles 3 hard 0 soft 0.28 temp 1 loss 4.37 helix 3.58 pae 0.36 i_pae 0.47 con 1.81 i_con 3.38 plddt 0.83 ptm 0.66 i_ptm 0.56 rg 0.08
# 58 models [2] recycles 3 hard 0 soft 0.32 temp 1 loss 4.39 helix 3.73 pae 0.41 i_pae 0.54 con 1.82 i_con 3.39 plddt 0.83 ptm 0.60 i_ptm 0.51 rg 0.16
# 59 models [2] recycles 3 hard 0 soft 0.36 temp 1 loss 4.85 helix 3.35 pae 0.41 i_pae 0.54 con 1.98 i_con 3.47 plddt 0.80 ptm 0.61 i_ptm 0.55 rg 0.49
# 60 models [2] recycles 3 hard 0 soft 0.40 temp 1 loss 4.17 helix 3.77 pae 0.39 i_pae 0.51 con 1.82 i_con 3.18 plddt 0.84 ptm 0.61 i_ptm 0.60 rg 0.18
# 61 models [0] recycles 3 hard 0 soft 0.44 temp 1 loss 7.62 helix 2.20 pae 0.70 i_pae 0.88 con 2.61 i_con 5.16 plddt 0.57 ptm 0.51 i_ptm 0.10 rg 0.18
# 62 models [1] recycles 3 hard 0 soft 0.48 temp 1 loss 4.27 helix 3.73 pae 0.37 i_pae 0.48 con 1.81 i_con 3.28 plddt 0.83 ptm 0.66 i_ptm 0.59 rg 0.25
# 63 models [3] recycles 3 hard 0 soft 0.52 temp 1 loss 3.86 helix 3.82 pae 0.33 i_pae 0.42 con 1.86 i_con 2.88 plddt 0.85 ptm 0.67 i_ptm 0.75 rg 0.24
# 64 models [0] recycles 3 hard 0 soft 0.56 temp 1 loss 3.88 helix 3.84 pae 0.33 i_pae 0.42 con 1.81 i_con 2.94 plddt 0.85 ptm 0.68 i_ptm 0.72 rg 0.26
# 65 models [3] recycles 3 hard 0 soft 0.60 temp 1 loss 3.56 helix 4.10 pae 0.35 i_pae 0.47 con 1.76 i_con 2.74 plddt 0.87 ptm 0.62 i_ptm 0.77 rg 0.27
# 66 models [3] recycles 3 hard 0 soft 0.64 temp 1 loss 3.34 helix 4.17 pae 0.32 i_pae 0.42 con 1.73 i_con 2.59 plddt 0.88 ptm 0.66 i_ptm 0.80 rg 0.27
# 67 models [0] recycles 3 hard 0 soft 0.68 temp 1 loss 8.17 helix 2.04 pae 0.71 i_pae 0.79 con 3.57 i_con 4.43 plddt 0.40 ptm 0.55 i_ptm 0.25 rg 1.08
# 68 models [3] recycles 3 hard 0 soft 0.72 temp 1 loss 3.43 helix 4.16 pae 0.30 i_pae 0.39 con 1.74 i_con 2.67 plddt 0.87 ptm 0.70 i_ptm 0.79 rg 0.27
# 69 models [1] recycles 3 hard 0 soft 0.76 temp 1 loss 4.44 helix 3.40 pae 0.34 i_pae 0.42 con 2.12 i_con 3.04 plddt 0.79 ptm 0.71 i_ptm 0.70 rg 0.24
# 70 models [2] recycles 3 hard 0 soft 0.80 temp 1 loss 7.16 helix 2.20 pae 0.63 i_pae 0.69 con 3.46 i_con 3.90 plddt 0.46 ptm 0.58 i_ptm 0.38 rg 0.17
# 71 models [1] recycles 3 hard 0 soft 0.84 temp 1 loss 3.90 helix 3.76 pae 0.32 i_pae 0.40 con 1.86 i_con 2.93 plddt 0.84 ptm 0.71 i_ptm 0.72 rg 0.14
# 72 models [1] recycles 3 hard 0 soft 0.88 temp 1 loss 5.68 helix 2.93 pae 0.49 i_pae 0.56 con 2.68 i_con 3.49 plddt 0.63 ptm 0.65 i_ptm 0.54 rg 0.25
# 73 models [4] recycles 3 hard 0 soft 0.92 temp 1 loss 6.75 helix 2.46 pae 0.65 i_pae 0.74 con 3.21 i_con 3.73 plddt 0.49 ptm 0.52 i_ptm 0.40 rg 0.41
# 74 models [3] recycles 3 hard 0 soft 0.96 temp 1 loss 8.44 helix 2.12 pae 0.74 i_pae 0.87 con 3.61 i_con 4.95 plddt 0.39 ptm 0.53 i_ptm 0.12 rg 0.08
# 75 models [0] recycles 3 hard 0 soft 1 temp 1 loss 5.34 helix 3.00 pae 0.46 i_pae 0.57 con 2.28 i_con 3.60 plddt 0.71 ptm 0.61 i_ptm 0.52 rg 0.21
# Optimised logit trajectory pLDDT: 0.88
# Stage 2: Softmax Optimisation
# 76 models [1] recycles 3 hard 0 soft 1 temp 0.96 loss 8.57 helix 2.21 pae 0.78 i_pae 0.86 con 3.75 i_con 4.80 plddt 0.37 ptm 0.54 i_ptm 0.13 rg 0.59
# 77 models [4] recycles 3 hard 0 soft 1 temp 0.91 loss 7.69 helix 2.17 pae 0.71 i_pae 0.84 con 3.32 i_con 4.62 plddt 0.43 ptm 0.52 i_ptm 0.14 rg -0.22
# 78 models [0] recycles 3 hard 0 soft 1 temp 0.87 loss 6.02 helix 2.64 pae 0.51 i_pae 0.63 con 2.54 i_con 3.90 plddt 0.66 ptm 0.59 i_ptm 0.41 rg 0.14
# 79 models [1] recycles 3 hard 0 soft 1 temp 0.83 loss 8.45 helix 2.45 pae 0.77 i_pae 0.87 con 3.45 i_con 4.85 plddt 0.38 ptm 0.55 i_ptm 0.12 rg 1.29
# 80 models [3] recycles 3 hard 0 soft 1 temp 0.79 loss 5.79 helix 3.03 pae 0.53 i_pae 0.62 con 2.69 i_con 3.59 plddt 0.60 ptm 0.60 i_ptm 0.48 rg 0.25
# 81 models [0] recycles 3 hard 0 soft 1 temp 0.75 loss 5.36 helix 2.93 pae 0.45 i_pae 0.55 con 2.36 i_con 3.56 plddt 0.71 ptm 0.63 i_ptm 0.58 rg 0.09
# 82 models [4] recycles 3 hard 0 soft 1 temp 0.72 loss 5.92 helix 2.74 pae 0.56 i_pae 0.73 con 2.46 i_con 3.93 plddt 0.68 ptm 0.53 i_ptm 0.38 rg -0.04
# 83 models [0] recycles 3 hard 0 soft 1 temp 0.68 loss 5.02 helix 3.18 pae 0.41 i_pae 0.52 con 2.24 i_con 3.43 plddt 0.75 ptm 0.64 i_ptm 0.61 rg 0.13
# 84 models [1] recycles 3 hard 0 soft 1 temp 0.64 loss 4.97 helix 3.29 pae 0.42 i_pae 0.52 con 2.21 i_con 3.42 plddt 0.75 ptm 0.65 i_ptm 0.53 rg 0.20
# 85 models [1] recycles 3 hard 0 soft 1 temp 0.61 loss 5.77 helix 2.88 pae 0.51 i_pae 0.64 con 2.46 i_con 3.88 plddt 0.67 ptm 0.61 i_ptm 0.38 rg -0.13
# 86 models [4] recycles 3 hard 0 soft 1 temp 0.58 loss 6.38 helix 2.29 pae 0.58 i_pae 0.72 con 2.80 i_con 3.96 plddt 0.60 ptm 0.53 i_ptm 0.38 rg -0.25
# 87 models [4] recycles 3 hard 0 soft 1 temp 0.54 loss 4.81 helix 3.23 pae 0.47 i_pae 0.62 con 2.16 i_con 3.32 plddt 0.75 ptm 0.56 i_ptm 0.57 rg 0.03
# 88 models [1] recycles 3 hard 0 soft 1 temp 0.51 loss 4.52 helix 3.41 pae 0.35 i_pae 0.44 con 2.14 i_con 3.17 plddt 0.79 ptm 0.69 i_ptm 0.67 rg 0.06
# 89 models [4] recycles 3 hard 0 soft 1 temp 0.48 loss 6.02 helix 2.36 pae 0.55 i_pae 0.67 con 2.67 i_con 3.77 plddt 0.63 ptm 0.57 i_ptm 0.42 rg -0.21
# 90 models [3] recycles 3 hard 0 soft 1 temp 0.45 loss 7.39 helix 2.20 pae 0.68 i_pae 0.84 con 2.74 i_con 4.85 plddt 0.53 ptm 0.55 i_ptm 0.13 rg 0.02
# 91 models [1] recycles 3 hard 0 soft 1 temp 0.42 loss 5.41 helix 2.63 pae 0.43 i_pae 0.53 con 2.41 i_con 3.58 plddt 0.71 ptm 0.66 i_ptm 0.54 rg -0.23
# 92 models [4] recycles 3 hard 0 soft 1 temp 0.39 loss 6.41 helix 2.19 pae 0.58 i_pae 0.70 con 2.73 i_con 3.98 plddt 0.59 ptm 0.57 i_ptm 0.35 rg -0.04
# 93 models [2] recycles 3 hard 0 soft 1 temp 0.37 loss 7.13 helix 2.30 pae 0.68 i_pae 0.85 con 2.71 i_con 4.77 plddt 0.56 ptm 0.50 i_ptm 0.13 rg -0.32
# 94 models [0] recycles 3 hard 0 soft 1 temp 0.34 loss 4.14 helix 3.50 pae 0.34 i_pae 0.43 con 1.95 i_con 2.97 plddt 0.82 ptm 0.69 i_ptm 0.71 rg 0.21
# 95 models [3] recycles 3 hard 0 soft 1 temp 0.32 loss 5.83 helix 3.27 pae 0.57 i_pae 0.78 con 2.05 i_con 4.39 plddt 0.75 ptm 0.54 i_ptm 0.22 rg -0.01
# 96 models [3] recycles 3 hard 0 soft 1 temp 0.29 loss 8.88 helix 2.24 pae 0.78 i_pae 0.88 con 3.57 i_con 4.96 plddt 0.37 ptm 0.54 i_ptm 0.12 rg 1.72
# 97 models [3] recycles 3 hard 0 soft 1 temp 0.27 loss 3.97 helix 3.73 pae 0.33 i_pae 0.41 con 1.93 i_con 2.90 plddt 0.83 ptm 0.71 i_ptm 0.74 rg 0.16
# 98 models [1] recycles 3 hard 0 soft 1 temp 0.25 loss 4.43 helix 3.40 pae 0.37 i_pae 0.48 con 1.97 i_con 3.22 plddt 0.80 ptm 0.66 i_ptm 0.60 rg 0.05
# 99 models [1] recycles 3 hard 0 soft 1 temp 0.23 loss 9.28 helix 2.03 pae 0.73 i_pae 0.78 con 3.98 i_con 4.35 plddt 0.37 ptm 0.60 i_ptm 0.22 rg 3.61
# 100 models [1] recycles 3 hard 0 soft 1 temp 0.21 loss 7.08 helix 2.54 pae 0.63 i_pae 0.71 con 3.22 i_con 4.08 plddt 0.51 ptm 0.60 i_ptm 0.35 rg 0.45
# 101 models [4] recycles 3 hard 0 soft 1 temp 0.19 loss 7.94 helix 2.20 pae 0.73 i_pae 0.84 con 3.52 i_con 4.61 plddt 0.40 ptm 0.56 i_ptm 0.15 rg -0.04
# 102 models [4] recycles 3 hard 0 soft 1 temp 0.17 loss 7.12 helix 2.50 pae 0.68 i_pae 0.86 con 2.68 i_con 4.81 plddt 0.56 ptm 0.52 i_ptm 0.12 rg -0.22
# 103 models [1] recycles 3 hard 0 soft 1 temp 0.15 loss 9.63 helix 2.15 pae 0.75 i_pae 0.79 con 4.01 i_con 4.39 plddt 0.38 ptm 0.60 i_ptm 0.42 rg 4.67
# 104 models [0] recycles 3 hard 0 soft 1 temp 0.14 loss 8.43 helix 2.13 pae 0.77 i_pae 0.88 con 3.52 i_con 4.96 plddt 0.39 ptm 0.53 i_ptm 0.11 rg 0.31
# 105 models [1] recycles 3 hard 0 soft 1 temp 0.12 loss 9.31 helix 2.12 pae 0.79 i_pae 0.88 con 3.72 i_con 4.91 plddt 0.37 ptm 0.56 i_ptm 0.11 rg 2.68
# 106 models [0] recycles 3 hard 0 soft 1 temp 0.11 loss 7.22 helix 2.45 pae 0.68 i_pae 0.89 con 2.45 i_con 5.13 plddt 0.61 ptm 0.52 i_ptm 0.09 rg -0.22
# 107 models [0] recycles 3 hard 0 soft 1 temp 0.09 loss 7.31 helix 2.45 pae 0.68 i_pae 0.87 con 2.49 i_con 5.15 plddt 0.61 ptm 0.53 i_ptm 0.11 rg -0.13
# 108 models [3] recycles 3 hard 0 soft 1 temp 0.08 loss 7.98 helix 2.44 pae 0.74 i_pae 0.89 con 3.29 i_con 5.00 plddt 0.45 ptm 0.54 i_ptm 0.11 rg -0.20
# 109 models [1] recycles 3 hard 0 soft 1 temp 0.07 loss 9.50 helix 2.14 pae 0.77 i_pae 0.82 con 3.83 i_con 4.57 plddt 0.36 ptm 0.58 i_ptm 0.17 rg 4.16
# 110 models [0] recycles 3 hard 0 soft 1 temp 0.06 loss 7.40 helix 2.34 pae 0.70 i_pae 0.88 con 2.61 i_con 5.10 plddt 0.56 ptm 0.52 i_ptm 0.10 rg -0.22
# 111 models [0] recycles 3 hard 0 soft 1 temp 0.05 loss 7.58 helix 2.23 pae 0.72 i_pae 0.89 con 2.67 i_con 5.15 plddt 0.54 ptm 0.52 i_ptm 0.10 rg -0.12
# 112 models [3] recycles 3 hard 0 soft 1 temp 0.04 loss 7.77 helix 2.58 pae 0.73 i_pae 0.87 con 3.22 i_con 4.95 plddt 0.45 ptm 0.54 i_ptm 0.12 rg -0.33
# 113 models [1] recycles 3 hard 0 soft 1 temp 0.03 loss 10.12 helix 2.04 pae 0.80 i_pae 0.84 con 4.18 i_con 4.67 plddt 0.32 ptm 0.58 i_ptm 0.15 rg 4.58
# 114 models [0] recycles 3 hard 0 soft 1 temp 0.03 loss 7.45 helix 2.32 pae 0.70 i_pae 0.88 con 2.64 i_con 5.13 plddt 0.56 ptm 0.53 i_ptm 0.10 rg -0.26
# 115 models [3] recycles 3 hard 0 soft 1 temp 0.02 loss 7.22 helix 2.92 pae 0.70 i_pae 0.88 con 2.73 i_con 5.01 plddt 0.56 ptm 0.53 i_ptm 0.10 rg -0.33
# 116 models [4] recycles 3 hard 0 soft 1 temp 0.02 loss 7.00 helix 2.59 pae 0.68 i_pae 0.86 con 2.59 i_con 4.81 plddt 0.59 ptm 0.53 i_ptm 0.12 rg -0.21
# 117 models [3] recycles 3 hard 0 soft 1 temp 0.01 loss 7.86 helix 2.59 pae 0.75 i_pae 0.90 con 3.23 i_con 5.04 plddt 0.46 ptm 0.54 i_ptm 0.10 rg -0.39
# 118 models [3] recycles 3 hard 0 soft 1 temp 0.01 loss 7.82 helix 2.54 pae 0.74 i_pae 0.88 con 3.23 i_con 4.97 plddt 0.46 ptm 0.55 i_ptm 0.11 rg -0.36
# 119 models [0] recycles 3 hard 0 soft 1 temp 0.01 loss 7.69 helix 2.21 pae 0.71 i_pae 0.89 con 2.73 i_con 5.23 plddt 0.54 ptm 0.52 i_ptm 0.09 rg -0.22
# 120 models [3] recycles 3 hard 0 soft 1 temp 0.01 loss 7.30 helix 2.69 pae 0.70 i_pae 0.88 con 2.70 i_con 5.04 plddt 0.55 ptm 0.55 i_ptm 0.11 rg -0.30
# Softmax trajectory pLDDT good, continuing: 0.83
# Stage 3: One-hot Optimisation
# 121 models [2] recycles 3 hard 1 soft 1 temp 0.01 loss 7.59 helix 2.57 pae 0.71 i_pae 0.83 con 3.29 i_con 4.71 plddt 0.40 ptm 0.54 i_ptm 0.14 rg -0.33
# 122 models [4] recycles 3 hard 1 soft 1 temp 0.01 loss 7.11 helix 2.67 pae 0.68 i_pae 0.85 con 2.67 i_con 4.80 plddt 0.49 ptm 0.53 i_ptm 0.13 rg -0.04
# 123 models [3] recycles 3 hard 1 soft 1 temp 0.01 loss 7.75 helix 2.64 pae 0.72 i_pae 0.87 con 3.14 i_con 5.02 plddt 0.44 ptm 0.54 i_ptm 0.11 rg -0.29
# 124 models [0] recycles 3 hard 1 soft 1 temp 0.01 loss 7.38 helix 2.40 pae 0.69 i_pae 0.87 con 2.55 i_con 5.15 plddt 0.52 ptm 0.52 i_ptm 0.11 rg -0.18
# 125 models [4] recycles 3 hard 1 soft 1 temp 0.01 loss 7.11 helix 2.67 pae 0.68 i_pae 0.85 con 2.67 i_con 4.80 plddt 0.49 ptm 0.53 i_ptm 0.13 rg -0.04
# One-hot trajectory pLDDT too low to continue: 0.49
# Severe clashes detected, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 10 minutes, 49 seconds
#
# Starting trajectory: PEDV_CTD_binder_l74_s903275
# Stage 1: Test Logits
# 1 models [2] recycles 1 hard 0 soft 0.02 temp 1 loss 12.59 helix 1.52 pae 0.85 i_pae 0.88 con 4.80 i_con 4.51 plddt 0.24 ptm 0.56 i_ptm 0.11 rg 10.61
# 2 models [3] recycles 1 hard 0 soft 0.04 temp 1 loss 11.41 helix 2.23 pae 0.80 i_pae 0.84 con 4.52 i_con 4.42 plddt 0.32 ptm 0.61 i_ptm 0.16 rg 8.75
# 3 models [0] recycles 1 hard 0 soft 0.05 temp 1 loss 10.36 helix 1.88 pae 0.78 i_pae 0.84 con 4.49 i_con 4.62 plddt 0.35 ptm 0.58 i_ptm 0.14 rg 4.37
# 4 models [2] recycles 1 hard 0 soft 0.07 temp 1 loss 10.72 helix 1.99 pae 0.76 i_pae 0.80 con 4.57 i_con 4.43 plddt 0.39 ptm 0.60 i_ptm 0.18 rg 6.14
# 5 models [2] recycles 1 hard 0 soft 0.09 temp 1 loss 9.94 helix 2.05 pae 0.76 i_pae 0.81 con 4.28 i_con 4.29 plddt 0.34 ptm 0.58 i_ptm 0.18 rg 4.96
# 6 models [1] recycles 1 hard 0 soft 0.11 temp 1 loss 9.74 helix 2.37 pae 0.72 i_pae 0.75 con 4.15 i_con 4.20 plddt 0.37 ptm 0.64 i_ptm 0.28 rg 5.46
# 7 models [1] recycles 1 hard 0 soft 0.13 temp 1 loss 8.56 helix 2.75 pae 0.71 i_pae 0.77 con 3.72 i_con 4.30 plddt 0.37 ptm 0.62 i_ptm 0.19 rg 3.01
# 8 models [3] recycles 1 hard 0 soft 0.14 temp 1 loss 8.30 helix 2.44 pae 0.69 i_pae 0.76 con 3.56 i_con 4.25 plddt 0.38 ptm 0.62 i_ptm 0.20 rg 2.56
# 9 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 8.48 helix 2.45 pae 0.71 i_pae 0.78 con 3.73 i_con 4.23 plddt 0.35 ptm 0.56 i_ptm 0.18 rg 2.58
# 10 models [2] recycles 1 hard 0 soft 0.18 temp 1 loss 8.27 helix 2.44 pae 0.71 i_pae 0.79 con 3.68 i_con 4.25 plddt 0.35 ptm 0.55 i_ptm 0.17 rg 1.99
# 11 models [1] recycles 1 hard 0 soft 0.20 temp 1 loss 8.03 helix 2.64 pae 0.73 i_pae 0.82 con 3.45 i_con 4.50 plddt 0.40 ptm 0.60 i_ptm 0.14 rg 1.33
# 12 models [2] recycles 1 hard 0 soft 0.22 temp 1 loss 7.68 helix 2.74 pae 0.69 i_pae 0.79 con 3.31 i_con 4.33 plddt 0.43 ptm 0.57 i_ptm 0.18 rg 1.38
# 13 models [1] recycles 1 hard 0 soft 0.23 temp 1 loss 7.40 helix 2.91 pae 0.67 i_pae 0.76 con 3.19 i_con 4.25 plddt 0.47 ptm 0.61 i_ptm 0.19 rg 1.35
# 14 models [1] recycles 1 hard 0 soft 0.25 temp 1 loss 7.32 helix 3.15 pae 0.69 i_pae 0.80 con 3.05 i_con 4.38 plddt 0.45 ptm 0.60 i_ptm 0.16 rg 1.29
# 15 models [0] recycles 1 hard 0 soft 0.27 temp 1 loss 7.40 helix 3.08 pae 0.70 i_pae 0.81 con 3.05 i_con 4.50 plddt 0.44 ptm 0.57 i_ptm 0.14 rg 1.04
# 16 models [3] recycles 1 hard 0 soft 0.29 temp 1 loss 6.89 helix 3.46 pae 0.67 i_pae 0.79 con 2.77 i_con 4.30 plddt 0.49 ptm 0.59 i_ptm 0.16 rg 1.39
# 17 models [1] recycles 1 hard 0 soft 0.31 temp 1 loss 7.25 helix 3.07 pae 0.67 i_pae 0.79 con 2.99 i_con 4.33 plddt 0.50 ptm 0.60 i_ptm 0.17 rg 1.37
# 18 models [3] recycles 1 hard 0 soft 0.32 temp 1 loss 6.74 helix 3.51 pae 0.66 i_pae 0.77 con 2.79 i_con 4.25 plddt 0.49 ptm 0.60 i_ptm 0.18 rg 1.07
# 19 models [1] recycles 1 hard 0 soft 0.34 temp 1 loss 6.78 helix 3.62 pae 0.67 i_pae 0.80 con 2.66 i_con 4.39 plddt 0.53 ptm 0.59 i_ptm 0.15 rg 1.26
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 6.52 helix 3.72 pae 0.66 i_pae 0.78 con 2.58 i_con 4.22 plddt 0.53 ptm 0.59 i_ptm 0.17 rg 1.37
# 21 models [1] recycles 1 hard 0 soft 0.38 temp 1 loss 6.50 helix 4.03 pae 0.66 i_pae 0.81 con 2.46 i_con 4.45 plddt 0.56 ptm 0.59 i_ptm 0.13 rg 1.23
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 6.23 helix 3.97 pae 0.64 i_pae 0.77 con 2.47 i_con 4.15 plddt 0.56 ptm 0.55 i_ptm 0.19 rg 1.31
# 23 models [0] recycles 1 hard 0 soft 0.41 temp 1 loss 6.38 helix 3.93 pae 0.64 i_pae 0.77 con 2.50 i_con 4.22 plddt 0.56 ptm 0.56 i_ptm 0.17 rg 1.39
# 24 models [2] recycles 1 hard 0 soft 0.43 temp 1 loss 6.12 helix 4.06 pae 0.62 i_pae 0.76 con 2.39 i_con 4.09 plddt 0.58 ptm 0.57 i_ptm 0.20 rg 1.50
# 25 models [2] recycles 1 hard 0 soft 0.45 temp 1 loss 5.80 helix 4.43 pae 0.62 i_pae 0.77 con 2.12 i_con 4.19 plddt 0.65 ptm 0.58 i_ptm 0.17 rg 1.39
# 26 models [1] recycles 1 hard 0 soft 0.47 temp 1 loss 6.28 helix 4.22 pae 0.64 i_pae 0.79 con 2.33 i_con 4.37 plddt 0.61 ptm 0.60 i_ptm 0.15 rg 1.44
# 27 models [3] recycles 1 hard 0 soft 0.49 temp 1 loss 5.86 helix 4.65 pae 0.64 i_pae 0.81 con 2.00 i_con 4.39 plddt 0.69 ptm 0.57 i_ptm 0.12 rg 1.54
# 28 models [0] recycles 1 hard 0 soft 0.50 temp 1 loss 5.43 helix 4.81 pae 0.59 i_pae 0.75 con 1.88 i_con 4.16 plddt 0.71 ptm 0.57 i_ptm 0.18 rg 1.50
# 29 models [4] recycles 1 hard 0 soft 0.52 temp 1 loss 5.73 helix 4.57 pae 0.62 i_pae 0.79 con 1.97 i_con 4.26 plddt 0.67 ptm 0.58 i_ptm 0.15 rg 1.56
# 30 models [1] recycles 1 hard 0 soft 0.54 temp 1 loss 5.74 helix 4.89 pae 0.63 i_pae 0.81 con 1.84 i_con 4.51 plddt 0.71 ptm 0.59 i_ptm 0.12 rg 1.51
# 31 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 5.44 helix 4.56 pae 0.58 i_pae 0.72 con 2.04 i_con 3.92 plddt 0.68 ptm 0.58 i_ptm 0.24 rg 1.56
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 6.11 helix 3.95 pae 0.62 i_pae 0.77 con 2.33 i_con 4.15 plddt 0.60 ptm 0.58 i_ptm 0.17 rg 1.38
# 33 models [3] recycles 1 hard 0 soft 0.59 temp 1 loss 5.40 helix 4.88 pae 0.60 i_pae 0.77 con 1.83 i_con 4.19 plddt 0.72 ptm 0.57 i_ptm 0.16 rg 1.50
# 34 models [2] recycles 1 hard 0 soft 0.61 temp 1 loss 5.54 helix 4.53 pae 0.59 i_pae 0.74 con 2.12 i_con 3.99 plddt 0.64 ptm 0.57 i_ptm 0.22 rg 1.34
# 35 models [1] recycles 1 hard 0 soft 0.63 temp 1 loss 5.60 helix 4.72 pae 0.61 i_pae 0.77 con 1.93 i_con 4.27 plddt 0.69 ptm 0.60 i_ptm 0.16 rg 1.40
# 36 models [3] recycles 1 hard 0 soft 0.65 temp 1 loss 7.17 helix 3.27 pae 0.69 i_pae 0.79 con 3.01 i_con 4.26 plddt 0.47 ptm 0.58 i_ptm 0.17 rg 1.44
# 37 models [2] recycles 1 hard 0 soft 0.67 temp 1 loss 5.39 helix 5.15 pae 0.63 i_pae 0.81 con 1.78 i_con 4.32 plddt 0.73 ptm 0.55 i_ptm 0.14 rg 1.47
# 38 models [2] recycles 1 hard 0 soft 0.68 temp 1 loss 5.18 helix 5.08 pae 0.60 i_pae 0.76 con 1.82 i_con 4.05 plddt 0.71 ptm 0.56 i_ptm 0.19 rg 1.49
# 39 models [2] recycles 1 hard 0 soft 0.70 temp 1 loss 5.09 helix 5.09 pae 0.59 i_pae 0.76 con 1.75 i_con 4.07 plddt 0.73 ptm 0.57 i_ptm 0.19 rg 1.42
# 40 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 7.05 helix 3.29 pae 0.68 i_pae 0.80 con 2.87 i_con 4.38 plddt 0.50 ptm 0.59 i_ptm 0.16 rg 1.14
# 41 models [3] recycles 1 hard 0 soft 0.74 temp 1 loss 5.68 helix 4.60 pae 0.62 i_pae 0.79 con 1.95 i_con 4.29 plddt 0.70 ptm 0.58 i_ptm 0.15 rg 1.38
# 42 models [1] recycles 1 hard 0 soft 0.76 temp 1 loss 5.40 helix 5.03 pae 0.59 i_pae 0.75 con 1.89 i_con 4.21 plddt 0.70 ptm 0.60 i_ptm 0.18 rg 1.44
# 43 models [4] recycles 1 hard 0 soft 0.77 temp 1 loss 5.39 helix 4.81 pae 0.61 i_pae 0.78 con 1.79 i_con 4.20 plddt 0.71 ptm 0.58 i_ptm 0.18 rg 1.48
# 44 models [1] recycles 1 hard 0 soft 0.79 temp 1 loss 5.63 helix 4.71 pae 0.61 i_pae 0.77 con 1.91 i_con 4.31 plddt 0.71 ptm 0.59 i_ptm 0.16 rg 1.46
# 45 models [0] recycles 1 hard 0 soft 0.81 temp 1 loss 5.49 helix 4.52 pae 0.57 i_pae 0.72 con 2.02 i_con 4.05 plddt 0.67 ptm 0.58 i_ptm 0.23 rg 1.35
# 46 models [0] recycles 1 hard 0 soft 0.83 temp 1 loss 5.68 helix 4.85 pae 0.62 i_pae 0.79 con 1.94 i_con 4.37 plddt 0.66 ptm 0.56 i_ptm 0.14 rg 1.42
# 47 models [4] recycles 1 hard 0 soft 0.85 temp 1 loss 5.39 helix 4.72 pae 0.60 i_pae 0.76 con 1.91 i_con 4.07 plddt 0.69 ptm 0.57 i_ptm 0.19 rg 1.49
# 48 models [0] recycles 1 hard 0 soft 0.86 temp 1 loss 5.22 helix 4.63 pae 0.55 i_pae 0.70 con 1.91 i_con 3.91 plddt 0.70 ptm 0.59 i_ptm 0.26 rg 1.43
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 5.89 helix 3.98 pae 0.60 i_pae 0.74 con 2.27 i_con 4.07 plddt 0.61 ptm 0.59 i_ptm 0.20 rg 1.19
# 50 models [3] recycles 1 hard 0 soft 0.90 temp 1 loss 6.07 helix 4.25 pae 0.65 i_pae 0.83 con 2.04 i_con 4.52 plddt 0.69 ptm 0.57 i_ptm 0.12 rg 1.20
# Initial trajectory pLDDT good, continuing: 0.73
# Beta sheeted trajectory detected, optimising settings
# Stage 1: Additional Logits Optimisation
# 51 models [1] recycles 3 hard 0 soft 0.04 temp 1 loss 6.40 helix 3.65 pae 0.65 i_pae 0.81 con 2.23 i_con 4.45 plddt 0.65 ptm 0.60 i_ptm 0.15 rg 1.33
# 52 models [2] recycles 3 hard 0 soft 0.08 temp 1 loss 5.75 helix 4.21 pae 0.62 i_pae 0.78 con 2.00 i_con 4.17 plddt 0.69 ptm 0.55 i_ptm 0.18 rg 1.47
# 53 models [3] recycles 3 hard 0 soft 0.12 temp 1 loss 6.05 helix 4.19 pae 0.66 i_pae 0.82 con 1.93 i_con 4.50 plddt 0.68 ptm 0.57 i_ptm 0.12 rg 1.54
# 54 models [3] recycles 3 hard 0 soft 0.16 temp 1 loss 5.72 helix 4.55 pae 0.64 i_pae 0.81 con 1.83 i_con 4.40 plddt 0.70 ptm 0.56 i_ptm 0.13 rg 1.50
# 55 models [1] recycles 3 hard 0 soft 0.20 temp 1 loss 5.57 helix 4.59 pae 0.61 i_pae 0.78 con 1.84 i_con 4.28 plddt 0.72 ptm 0.60 i_ptm 0.16 rg 1.44
# 56 models [3] recycles 3 hard 0 soft 0.24 temp 1 loss 5.84 helix 4.70 pae 0.65 i_pae 0.83 con 1.80 i_con 4.60 plddt 0.70 ptm 0.58 i_ptm 0.11 rg 1.45
# 57 models [4] recycles 3 hard 0 soft 0.28 temp 1 loss 5.36 helix 4.78 pae 0.63 i_pae 0.81 con 1.75 i_con 4.20 plddt 0.70 ptm 0.52 i_ptm 0.17 rg 1.50
# 58 models [3] recycles 3 hard 0 soft 0.32 temp 1 loss 5.35 helix 4.98 pae 0.63 i_pae 0.80 con 1.74 i_con 4.27 plddt 0.73 ptm 0.56 i_ptm 0.14 rg 1.42
# 59 models [0] recycles 3 hard 0 soft 0.36 temp 1 loss 5.15 helix 4.97 pae 0.59 i_pae 0.75 con 1.73 i_con 4.09 plddt 0.73 ptm 0.57 i_ptm 0.21 rg 1.51
# 60 models [2] recycles 3 hard 0 soft 0.40 temp 1 loss 5.03 helix 5.07 pae 0.59 i_pae 0.75 con 1.69 i_con 4.03 plddt 0.74 ptm 0.55 i_ptm 0.20 rg 1.53
# 61 models [1] recycles 3 hard 0 soft 0.44 temp 1 loss 5.43 helix 4.81 pae 0.60 i_pae 0.77 con 1.76 i_con 4.30 plddt 0.72 ptm 0.59 i_ptm 0.15 rg 1.43
# 62 models [3] recycles 3 hard 0 soft 0.48 temp 1 loss 5.55 helix 5.13 pae 0.65 i_pae 0.84 con 1.67 i_con 4.55 plddt 0.73 ptm 0.54 i_ptm 0.11 rg 1.53
# 63 models [1] recycles 3 hard 0 soft 0.52 temp 1 loss 5.47 helix 4.65 pae 0.60 i_pae 0.76 con 1.83 i_con 4.18 plddt 0.70 ptm 0.59 i_ptm 0.19 rg 1.58
# 64 models [2] recycles 3 hard 0 soft 0.56 temp 1 loss 4.93 helix 4.75 pae 0.55 i_pae 0.70 con 1.83 i_con 3.70 plddt 0.75 ptm 0.58 i_ptm 0.31 rg 1.57
# 65 models [0] recycles 3 hard 0 soft 0.60 temp 1 loss 4.73 helix 4.67 pae 0.50 i_pae 0.62 con 1.87 i_con 3.45 plddt 0.75 ptm 0.61 i_ptm 0.41 rg 1.67
# 66 models [2] recycles 3 hard 0 soft 0.64 temp 1 loss 4.92 helix 4.57 pae 0.54 i_pae 0.69 con 1.89 i_con 3.59 plddt 0.74 ptm 0.56 i_ptm 0.35 rg 1.60
# 67 models [3] recycles 3 hard 0 soft 0.68 temp 1 loss 4.45 helix 4.82 pae 0.47 i_pae 0.58 con 1.85 i_con 3.28 plddt 0.76 ptm 0.63 i_ptm 0.47 rg 1.56
# 68 models [3] recycles 3 hard 0 soft 0.72 temp 1 loss 4.92 helix 4.56 pae 0.51 i_pae 0.63 con 1.93 i_con 3.57 plddt 0.74 ptm 0.62 i_ptm 0.38 rg 1.54
# 69 models [4] recycles 3 hard 0 soft 0.76 temp 1 loss 5.11 helix 4.92 pae 0.60 i_pae 0.77 con 1.77 i_con 3.97 plddt 0.72 ptm 0.54 i_ptm 0.22 rg 1.52
# 70 models [1] recycles 3 hard 0 soft 0.80 temp 1 loss 5.23 helix 4.84 pae 0.58 i_pae 0.74 con 1.77 i_con 4.09 plddt 0.73 ptm 0.59 i_ptm 0.20 rg 1.47
# 71 models [0] recycles 3 hard 0 soft 0.84 temp 1 loss 4.92 helix 4.37 pae 0.51 i_pae 0.63 con 1.90 i_con 3.53 plddt 0.73 ptm 0.60 i_ptm 0.39 rg 1.56
# 72 models [0] recycles 3 hard 0 soft 0.88 temp 1 loss 5.08 helix 4.38 pae 0.53 i_pae 0.67 con 1.89 i_con 3.73 plddt 0.72 ptm 0.61 i_ptm 0.33 rg 1.45
# 73 models [0] recycles 3 hard 0 soft 0.92 temp 1 loss 4.37 helix 4.76 pae 0.46 i_pae 0.57 con 1.78 i_con 3.26 plddt 0.77 ptm 0.63 i_ptm 0.48 rg 1.56
# 74 models [3] recycles 3 hard 0 soft 0.96 temp 1 loss 5.71 helix 4.23 pae 0.60 i_pae 0.75 con 2.08 i_con 4.10 plddt 0.67 ptm 0.59 i_ptm 0.22 rg 1.38
# 75 models [0] recycles 3 hard 0 soft 1 temp 1 loss 5.54 helix 4.22 pae 0.58 i_pae 0.72 con 2.01 i_con 3.91 plddt 0.68 ptm 0.58 i_ptm 0.28 rg 1.71
# Optimised logit trajectory pLDDT: 0.77
# Stage 2: Softmax Optimisation
# 76 models [3] recycles 3 hard 0 soft 1 temp 0.96 loss 5.04 helix 4.61 pae 0.55 i_pae 0.69 con 1.87 i_con 3.75 plddt 0.74 ptm 0.61 i_ptm 0.30 rg 1.49
# 77 models [4] recycles 3 hard 0 soft 1 temp 0.91 loss 5.12 helix 4.76 pae 0.59 i_pae 0.75 con 1.84 i_con 3.88 plddt 0.71 ptm 0.56 i_ptm 0.27 rg 1.49
# 78 models [0] recycles 3 hard 0 soft 1 temp 0.87 loss 5.27 helix 4.14 pae 0.52 i_pae 0.64 con 1.97 i_con 3.67 plddt 0.71 ptm 0.60 i_ptm 0.36 rg 1.80
# 79 models [2] recycles 3 hard 0 soft 1 temp 0.83 loss 4.17 helix 4.68 pae 0.46 i_pae 0.58 con 1.87 i_con 2.97 plddt 0.78 ptm 0.59 i_ptm 0.56 rg 1.53
# 80 models [2] recycles 3 hard 0 soft 1 temp 0.79 loss 4.25 helix 4.65 pae 0.45 i_pae 0.55 con 1.83 i_con 3.06 plddt 0.79 ptm 0.63 i_ptm 0.54 rg 1.59
# 81 models [1] recycles 3 hard 0 soft 1 temp 0.75 loss 5.38 helix 4.63 pae 0.58 i_pae 0.73 con 1.91 i_con 4.07 plddt 0.73 ptm 0.61 i_ptm 0.24 rg 1.37
# 82 models [0] recycles 3 hard 0 soft 1 temp 0.72 loss 5.05 helix 4.52 pae 0.55 i_pae 0.69 con 1.84 i_con 3.78 plddt 0.73 ptm 0.59 i_ptm 0.32 rg 1.44
# 83 models [2] recycles 3 hard 0 soft 1 temp 0.68 loss 4.41 helix 4.66 pae 0.47 i_pae 0.59 con 1.88 i_con 3.17 plddt 0.77 ptm 0.62 i_ptm 0.50 rg 1.55
# 84 models [2] recycles 3 hard 0 soft 1 temp 0.64 loss 4.39 helix 4.49 pae 0.46 i_pae 0.57 con 1.86 i_con 3.12 plddt 0.78 ptm 0.63 i_ptm 0.50 rg 1.57
# 85 models [2] recycles 3 hard 0 soft 1 temp 0.61 loss 3.89 helix 4.87 pae 0.46 i_pae 0.57 con 1.74 i_con 2.87 plddt 0.80 ptm 0.59 i_ptm 0.58 rg 1.55
# 86 models [2] recycles 3 hard 0 soft 1 temp 0.58 loss 5.14 helix 4.47 pae 0.57 i_pae 0.71 con 1.89 i_con 3.79 plddt 0.74 ptm 0.59 i_ptm 0.28 rg 1.48
# 87 models [1] recycles 3 hard 0 soft 1 temp 0.54 loss 5.56 helix 4.64 pae 0.61 i_pae 0.78 con 1.86 i_con 4.29 plddt 0.72 ptm 0.59 i_ptm 0.18 rg 1.36
# 88 models [0] recycles 3 hard 0 soft 1 temp 0.51 loss 5.94 helix 4.37 pae 0.64 i_pae 0.81 con 1.93 i_con 4.51 plddt 0.68 ptm 0.57 i_ptm 0.14 rg 1.30
# 89 models [2] recycles 3 hard 0 soft 1 temp 0.48 loss 3.69 helix 4.80 pae 0.37 i_pae 0.45 con 1.78 i_con 2.66 plddt 0.82 ptm 0.68 i_ptm 0.68 rg 1.51
# 90 models [3] recycles 3 hard 0 soft 1 temp 0.45 loss 4.35 helix 4.63 pae 0.43 i_pae 0.53 con 1.87 i_con 3.13 plddt 0.79 ptm 0.67 i_ptm 0.52 rg 1.58
# 91 models [3] recycles 3 hard 0 soft 1 temp 0.42 loss 3.36 helix 5.15 pae 0.38 i_pae 0.46 con 1.70 i_con 2.51 plddt 0.84 ptm 0.65 i_ptm 0.73 rg 1.58
# 92 models [1] recycles 3 hard 0 soft 1 temp 0.39 loss 5.63 helix 4.30 pae 0.60 i_pae 0.75 con 1.94 i_con 4.19 plddt 0.72 ptm 0.60 i_ptm 0.20 rg 1.38
# 93 models [0] recycles 3 hard 0 soft 1 temp 0.37 loss 3.96 helix 4.66 pae 0.39 i_pae 0.48 con 1.84 i_con 2.82 plddt 0.80 ptm 0.66 i_ptm 0.64 rg 1.51
# 94 models [3] recycles 3 hard 0 soft 1 temp 0.34 loss 3.58 helix 4.85 pae 0.35 i_pae 0.43 con 1.81 i_con 2.55 plddt 0.83 ptm 0.70 i_ptm 0.72 rg 1.56
# 95 models [2] recycles 3 hard 0 soft 1 temp 0.32 loss 3.46 helix 4.97 pae 0.38 i_pae 0.46 con 1.80 i_con 2.47 plddt 0.82 ptm 0.65 i_ptm 0.74 rg 1.52
# 96 models [0] recycles 3 hard 0 soft 1 temp 0.29 loss 4.72 helix 4.13 pae 0.44 i_pae 0.52 con 2.02 i_con 3.14 plddt 0.75 ptm 0.66 i_ptm 0.54 rg 1.74
# 97 models [4] recycles 3 hard 0 soft 1 temp 0.27 loss 4.78 helix 4.22 pae 0.48 i_pae 0.58 con 2.01 i_con 3.26 plddt 0.74 ptm 0.64 i_ptm 0.50 rg 1.55
# 98 models [4] recycles 3 hard 0 soft 1 temp 0.25 loss 5.12 helix 4.04 pae 0.50 i_pae 0.61 con 2.06 i_con 3.43 plddt 0.72 ptm 0.63 i_ptm 0.43 rg 1.75
# 99 models [4] recycles 3 hard 0 soft 1 temp 0.23 loss 4.57 helix 4.57 pae 0.49 i_pae 0.61 con 1.86 i_con 3.34 plddt 0.76 ptm 0.63 i_ptm 0.44 rg 1.43
# 100 models [2] recycles 3 hard 0 soft 1 temp 0.21 loss 3.61 helix 4.88 pae 0.38 i_pae 0.47 con 1.77 i_con 2.61 plddt 0.82 ptm 0.66 i_ptm 0.68 rg 1.50
# 101 models [2] recycles 3 hard 0 soft 1 temp 0.19 loss 3.68 helix 4.95 pae 0.39 i_pae 0.47 con 1.78 i_con 2.69 plddt 0.82 ptm 0.66 i_ptm 0.67 rg 1.53
# 102 models [4] recycles 3 hard 0 soft 1 temp 0.17 loss 5.10 helix 4.70 pae 0.57 i_pae 0.73 con 1.83 i_con 3.87 plddt 0.73 ptm 0.59 i_ptm 0.27 rg 1.47
# 103 models [1] recycles 3 hard 0 soft 1 temp 0.15 loss 5.76 helix 4.40 pae 0.62 i_pae 0.79 con 1.96 i_con 4.32 plddt 0.70 ptm 0.60 i_ptm 0.16 rg 1.34
# 104 models [4] recycles 3 hard 0 soft 1 temp 0.14 loss 4.40 helix 4.57 pae 0.49 i_pae 0.61 con 1.87 i_con 3.13 plddt 0.76 ptm 0.60 i_ptm 0.53 rg 1.55
# 105 models [1] recycles 3 hard 0 soft 1 temp 0.12 loss 5.91 helix 4.01 pae 0.60 i_pae 0.74 con 2.06 i_con 4.16 plddt 0.70 ptm 0.61 i_ptm 0.21 rg 1.70
# 106 models [4] recycles 3 hard 0 soft 1 temp 0.11 loss 4.83 helix 4.36 pae 0.52 i_pae 0.64 con 1.97 i_con 3.41 plddt 0.74 ptm 0.61 i_ptm 0.42 rg 1.44
# 107 models [4] recycles 3 hard 0 soft 1 temp 0.09 loss 5.25 helix 4.58 pae 0.58 i_pae 0.73 con 1.89 i_con 3.93 plddt 0.72 ptm 0.60 i_ptm 0.25 rg 1.45
# 108 models [3] recycles 3 hard 0 soft 1 temp 0.08 loss 3.47 helix 4.95 pae 0.36 i_pae 0.44 con 1.75 i_con 2.50 plddt 0.84 ptm 0.68 i_ptm 0.75 rg 1.61
# 109 models [4] recycles 3 hard 0 soft 1 temp 0.07 loss 4.81 helix 4.40 pae 0.51 i_pae 0.64 con 1.86 i_con 3.46 plddt 0.75 ptm 0.62 i_ptm 0.41 rg 1.58
# 110 models [1] recycles 3 hard 0 soft 1 temp 0.06 loss 4.93 helix 4.32 pae 0.51 i_pae 0.63 con 1.97 i_con 3.50 plddt 0.74 ptm 0.64 i_ptm 0.40 rg 1.47
# 111 models [0] recycles 3 hard 0 soft 1 temp 0.05 loss 4.80 helix 4.06 pae 0.45 i_pae 0.54 con 2.05 i_con 3.15 plddt 0.75 ptm 0.65 i_ptm 0.52 rg 1.80
# 112 models [3] recycles 3 hard 0 soft 1 temp 0.04 loss 5.26 helix 4.50 pae 0.57 i_pae 0.71 con 1.93 i_con 3.88 plddt 0.72 ptm 0.60 i_ptm 0.27 rg 1.45
# 113 models [0] recycles 3 hard 0 soft 1 temp 0.03 loss 5.00 helix 4.03 pae 0.46 i_pae 0.55 con 2.09 i_con 3.29 plddt 0.73 ptm 0.66 i_ptm 0.50 rg 1.83
# 114 models [4] recycles 3 hard 0 soft 1 temp 0.03 loss 4.69 helix 4.38 pae 0.49 i_pae 0.61 con 1.93 i_con 3.29 plddt 0.75 ptm 0.62 i_ptm 0.46 rg 1.54
# 115 models [4] recycles 3 hard 0 soft 1 temp 0.02 loss 4.13 helix 4.60 pae 0.42 i_pae 0.51 con 1.89 i_con 2.89 plddt 0.79 ptm 0.66 i_ptm 0.62 rg 1.58
# 116 models [4] recycles 3 hard 0 soft 1 temp 0.02 loss 5.35 helix 4.23 pae 0.56 i_pae 0.69 con 2.05 i_con 3.79 plddt 0.69 ptm 0.61 i_ptm 0.29 rg 1.35
# 117 models [4] recycles 3 hard 0 soft 1 temp 0.01 loss 5.16 helix 4.29 pae 0.55 i_pae 0.69 con 1.99 i_con 3.66 plddt 0.71 ptm 0.60 i_ptm 0.35 rg 1.48
# 118 models [0] recycles 3 hard 0 soft 1 temp 0.01 loss 5.59 helix 4.03 pae 0.55 i_pae 0.67 con 2.13 i_con 3.77 plddt 0.70 ptm 0.61 i_ptm 0.33 rg 1.78
# 119 models [1] recycles 3 hard 0 soft 1 temp 0.01 loss 5.79 helix 3.89 pae 0.57 i_pae 0.70 con 2.17 i_con 3.90 plddt 0.69 ptm 0.63 i_ptm 0.28 rg 1.75
# 120 models [0] recycles 3 hard 0 soft 1 temp 0.01 loss 4.93 helix 4.09 pae 0.47 i_pae 0.57 con 2.06 i_con 3.25 plddt 0.73 ptm 0.64 i_ptm 0.50 rg 1.85
# Softmax trajectory pLDDT good, continuing: 0.84
# Stage 3: One-hot Optimisation
# 121 models [1] recycles 3 hard 1 soft 1 temp 0.01 loss 4.39 helix 4.37 pae 0.42 i_pae 0.52 con 1.91 i_con 3.06 plddt 0.75 ptm 0.68 i_ptm 0.56 rg 1.56
# 122 models [4] recycles 3 hard 1 soft 1 temp 0.01 loss 4.19 helix 4.56 pae 0.44 i_pae 0.54 con 1.88 i_con 2.93 plddt 0.74 ptm 0.64 i_ptm 0.60 rg 1.60
# 123 models [0] recycles 3 hard 1 soft 1 temp 0.01 loss 4.60 helix 4.12 pae 0.42 i_pae 0.50 con 2.04 i_con 2.98 plddt 0.74 ptm 0.66 i_ptm 0.60 rg 1.85
# 124 models [4] recycles 3 hard 1 soft 1 temp 0.01 loss 4.19 helix 4.56 pae 0.44 i_pae 0.54 con 1.88 i_con 2.93 plddt 0.74 ptm 0.64 i_ptm 0.60 rg 1.60
# 125 models [0] recycles 3 hard 1 soft 1 temp 0.01 loss 4.50 helix 4.14 pae 0.41 i_pae 0.49 con 2.02 i_con 2.91 plddt 0.74 ptm 0.67 i_ptm 0.62 rg 1.85
# ...
# 75 models [3] recycles 1 hard 0 soft 1 temp 1 loss 9.24 helix 1.14 pae 0.76 i_pae 0.86 con 3.85 i_con 4.76 plddt 0.38 ptm 0.50 i_ptm 0.13 rg 1.58
# Optimised logit trajectory pLDDT: 0.88
# Stage 2: Softmax Optimisation
# 76 models [0] recycles 1 hard 0 soft 1 temp 0.96 loss 7.36 helix 1.69 pae 0.58 i_pae 0.83 con 2.02 i_con 4.96 plddt 0.74 ptm 0.49 i_ptm 0.14 rg 1.66
# 77 models [0] recycles 1 hard 0 soft 1 temp 0.91 loss 5.47 helix 1.98 pae 0.38 i_pae 0.53 con 1.85 i_con 3.40 plddt 0.82 ptm 0.60 i_ptm 0.60 rg 1.91
# 78 models [4] recycles 1 hard 0 soft 1 temp 0.87 loss 7.03 helix 1.56 pae 0.56 i_pae 0.78 con 2.16 i_con 4.45 plddt 0.71 ptm 0.50 i_ptm 0.22 rg 1.72
# 79 models [0] recycles 1 hard 0 soft 1 temp 0.83 loss 5.63 helix 1.72 pae 0.39 i_pae 0.53 con 1.98 i_con 3.37 plddt 0.81 ptm 0.62 i_ptm 0.58 rg 1.83
# 80 models [0] recycles 1 hard 0 soft 1 temp 0.79 loss 5.64 helix 1.81 pae 0.40 i_pae 0.53 con 1.96 i_con 3.40 plddt 0.80 ptm 0.61 i_ptm 0.57 rg 1.93
# 81 models [0] recycles 1 hard 0 soft 1 temp 0.75 loss 5.55 helix 2.01 pae 0.41 i_pae 0.58 con 1.79 i_con 3.62 plddt 0.83 ptm 0.58 i_ptm 0.54 rg 1.62
# 82 models [2] recycles 1 hard 0 soft 1 temp 0.72 loss 6.56 helix 1.66 pae 0.50 i_pae 0.70 con 2.02 i_con 4.17 plddt 0.78 ptm 0.53 i_ptm 0.30 rg 1.79
# 83 models [2] recycles 1 hard 0 soft 1 temp 0.68 loss 5.43 helix 1.92 pae 0.41 i_pae 0.57 con 1.80 i_con 3.41 plddt 0.84 ptm 0.60 i_ptm 0.53 rg 1.82
# 84 models [3] recycles 1 hard 0 soft 1 temp 0.64 loss 5.23 helix 2.08 pae 0.37 i_pae 0.51 con 1.71 i_con 3.33 plddt 0.85 ptm 0.63 i_ptm 0.60 rg 1.95
# 85 models [1] recycles 1 hard 0 soft 1 temp 0.61 loss 6.07 helix 1.82 pae 0.44 i_pae 0.60 con 1.92 i_con 3.83 plddt 0.79 ptm 0.59 i_ptm 0.41 rg 1.91
# 86 models [2] recycles 1 hard 0 soft 1 temp 0.58 loss 5.59 helix 1.94 pae 0.41 i_pae 0.57 con 1.81 i_con 3.55 plddt 0.83 ptm 0.59 i_ptm 0.49 rg 1.85
# 87 models [0] recycles 1 hard 0 soft 1 temp 0.54 loss 5.83 helix 1.81 pae 0.40 i_pae 0.55 con 1.92 i_con 3.60 plddt 0.81 ptm 0.61 i_ptm 0.52 rg 1.97
# 88 models [0] recycles 1 hard 0 soft 1 temp 0.51 loss 5.61 helix 1.83 pae 0.40 i_pae 0.54 con 1.90 i_con 3.47 plddt 0.82 ptm 0.61 i_ptm 0.53 rg 1.78
# 89 models [2] recycles 1 hard 0 soft 1 temp 0.48 loss 6.22 helix 2.06 pae 0.51 i_pae 0.74 con 1.71 i_con 4.29 plddt 0.82 ptm 0.52 i_ptm 0.25 rg 1.70
# 90 models [3] recycles 1 hard 0 soft 1 temp 0.45 loss 5.10 helix 2.16 pae 0.36 i_pae 0.50 con 1.67 i_con 3.25 plddt 0.86 ptm 0.64 i_ptm 0.58 rg 1.99
# 91 models [4] recycles 1 hard 0 soft 1 temp 0.42 loss 6.30 helix 1.78 pae 0.47 i_pae 0.64 con 2.06 i_con 3.98 plddt 0.76 ptm 0.59 i_ptm 0.38 rg 1.63
# 92 models [0] recycles 1 hard 0 soft 1 temp 0.39 loss 5.49 helix 2.04 pae 0.38 i_pae 0.52 con 1.90 i_con 3.41 plddt 0.83 ptm 0.62 i_ptm 0.55 rg 1.80
# 93 models [4] recycles 1 hard 0 soft 1 temp 0.37 loss 5.02 helix 2.16 pae 0.35 i_pae 0.49 con 1.59 i_con 3.31 plddt 0.87 ptm 0.64 i_ptm 0.59 rg 1.83
# 94 models [2] recycles 1 hard 0 soft 1 temp 0.34 loss 6.58 helix 1.99 pae 0.53 i_pae 0.77 con 1.76 i_con 4.58 plddt 0.81 ptm 0.52 i_ptm 0.18 rg 1.60
# 95 models [4] recycles 1 hard 0 soft 1 temp 0.32 loss 5.84 helix 1.86 pae 0.47 i_pae 0.67 con 1.76 i_con 3.84 plddt 0.81 ptm 0.57 i_ptm 0.37 rg 1.64
# 96 models [4] recycles 1 hard 0 soft 1 temp 0.29 loss 5.20 helix 1.98 pae 0.37 i_pae 0.51 con 1.65 i_con 3.35 plddt 0.85 ptm 0.64 i_ptm 0.56 rg 1.83
# 97 models [1] recycles 1 hard 0 soft 1 temp 0.27 loss 5.54 helix 1.93 pae 0.39 i_pae 0.54 con 1.76 i_con 3.54 plddt 0.82 ptm 0.63 i_ptm 0.46 rg 1.84
# 98 models [2] recycles 1 hard 0 soft 1 temp 0.25 loss 5.70 helix 2.00 pae 0.43 i_pae 0.61 con 1.75 i_con 3.75 plddt 0.83 ptm 0.57 i_ptm 0.45 rg 1.77
# 99 models [2] recycles 1 hard 0 soft 1 temp 0.23 loss 5.98 helix 1.96 pae 0.48 i_pae 0.69 con 1.75 i_con 4.02 plddt 0.83 ptm 0.56 i_ptm 0.33 rg 1.62
# 100 models [3] recycles 1 hard 0 soft 1 temp 0.21 loss 6.62 helix 1.84 pae 0.53 i_pae 0.76 con 1.81 i_con 4.46 plddt 0.79 ptm 0.54 i_ptm 0.21 rg 1.82
# 101 models [2] recycles 1 hard 0 soft 1 temp 0.19 loss 5.95 helix 1.99 pae 0.46 i_pae 0.66 con 1.80 i_con 3.88 plddt 0.83 ptm 0.56 i_ptm 0.37 rg 1.88
# 102 models [3] recycles 1 hard 0 soft 1 temp 0.17 loss 6.59 helix 1.81 pae 0.53 i_pae 0.74 con 1.92 i_con 4.31 plddt 0.78 ptm 0.54 i_ptm 0.23 rg 1.87
# 103 models [1] recycles 1 hard 0 soft 1 temp 0.15 loss 5.70 helix 1.88 pae 0.40 i_pae 0.54 con 1.83 i_con 3.59 plddt 0.82 ptm 0.64 i_ptm 0.48 rg 1.93
# 104 models [3] recycles 1 hard 0 soft 1 temp 0.14 loss 5.72 helix 1.80 pae 0.42 i_pae 0.57 con 1.91 i_con 3.55 plddt 0.82 ptm 0.62 i_ptm 0.46 rg 1.75
# 105 models [3] recycles 1 hard 0 soft 1 temp 0.12 loss 6.10 helix 1.82 pae 0.47 i_pae 0.66 con 1.83 i_con 3.94 plddt 0.82 ptm 0.58 i_ptm 0.34 rg 1.89
# 106 models [3] recycles 1 hard 0 soft 1 temp 0.11 loss 5.60 helix 1.92 pae 0.38 i_pae 0.52 con 1.91 i_con 3.47 plddt 0.83 ptm 0.65 i_ptm 0.53 rg 1.83
# 107 models [2] recycles 1 hard 0 soft 1 temp 0.09 loss 7.02 helix 1.72 pae 0.56 i_pae 0.77 con 2.07 i_con 4.60 plddt 0.75 ptm 0.53 i_ptm 0.19 rg 1.65
# 108 models [3] recycles 1 hard 0 soft 1 temp 0.08 loss 5.64 helix 1.94 pae 0.42 i_pae 0.58 con 1.85 i_con 3.58 plddt 0.83 ptm 0.61 i_ptm 0.47 rg 1.75
# 109 models [4] recycles 1 hard 0 soft 1 temp 0.07 loss 5.87 helix 1.80 pae 0.44 i_pae 0.60 con 1.89 i_con 3.69 plddt 0.80 ptm 0.62 i_ptm 0.43 rg 1.83
# 110 models [2] recycles 1 hard 0 soft 1 temp 0.06 loss 7.05 helix 1.68 pae 0.57 i_pae 0.80 con 2.10 i_con 4.67 plddt 0.76 ptm 0.53 i_ptm 0.18 rg 1.39
# 111 models [3] recycles 1 hard 0 soft 1 temp 0.05 loss 7.15 helix 1.62 pae 0.58 i_pae 0.79 con 2.09 i_con 4.63 plddt 0.73 ptm 0.53 i_ptm 0.18 rg 1.80
# 112 models [4] recycles 1 hard 0 soft 1 temp 0.04 loss 6.74 helix 1.65 pae 0.53 i_pae 0.72 con 2.09 i_con 4.30 plddt 0.74 ptm 0.57 i_ptm 0.27 rg 1.67
# 113 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 6.52 helix 1.69 pae 0.48 i_pae 0.63 con 2.18 i_con 3.89 plddt 0.74 ptm 0.61 i_ptm 0.40 rg 2.16
# 114 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 6.56 helix 1.83 pae 0.52 i_pae 0.74 con 1.97 i_con 4.27 plddt 0.77 ptm 0.56 i_ptm 0.26 rg 1.75
# 115 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 5.79 helix 1.84 pae 0.40 i_pae 0.55 con 1.94 i_con 3.59 plddt 0.81 ptm 0.61 i_ptm 0.50 rg 1.86
# 116 models [1] recycles 1 hard 0 soft 1 temp 0.02 loss 6.75 helix 1.67 pae 0.50 i_pae 0.66 con 2.23 i_con 4.12 plddt 0.72 ptm 0.60 i_ptm 0.37 rg 1.94
# 117 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 6.44 helix 1.71 pae 0.48 i_pae 0.64 con 2.01 i_con 4.06 plddt 0.76 ptm 0.60 i_ptm 0.37 rg 1.90
# 118 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 6.23 helix 1.68 pae 0.45 i_pae 0.60 con 2.05 i_con 3.82 plddt 0.76 ptm 0.61 i_ptm 0.40 rg 1.89
# 119 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 6.16 helix 1.80 pae 0.44 i_pae 0.60 con 1.94 i_con 3.87 plddt 0.79 ptm 0.61 i_ptm 0.40 rg 2.01
# 120 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 6.35 helix 1.71 pae 0.47 i_pae 0.64 con 2.05 i_con 3.97 plddt 0.77 ptm 0.61 i_ptm 0.37 rg 1.80
# Softmax trajectory pLDDT good, continuing: 0.87
# Stage 3: One-hot Optimisation
# 121 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 6.45 helix 1.82 pae 0.49 i_pae 0.68 con 1.95 i_con 4.15 plddt 0.74 ptm 0.58 i_ptm 0.31 rg 1.88
# 122 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 6.58 helix 1.65 pae 0.49 i_pae 0.65 con 2.15 i_con 4.06 plddt 0.71 ptm 0.57 i_ptm 0.31 rg 1.79
# 123 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 5.98 helix 1.93 pae 0.44 i_pae 0.62 con 1.75 i_con 3.92 plddt 0.80 ptm 0.58 i_ptm 0.36 rg 1.98
# 124 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.70 helix 1.89 pae 0.40 i_pae 0.55 con 1.79 i_con 3.62 plddt 0.78 ptm 0.64 i_ptm 0.48 rg 1.96
# 125 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 5.84 helix 1.90 pae 0.42 i_pae 0.58 con 1.79 i_con 3.78 plddt 0.79 ptm 0.62 i_ptm 0.42 rg 1.89
# One-hot trajectory pLDDT good, continuing: 0.78
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.95 helix 1.82 pae 0.42 i_pae 0.58 con 1.85 i_con 3.79 plddt 0.78 ptm 0.62 i_ptm 0.41 rg 1.91
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 6.06 helix 1.80 pae 0.44 i_pae 0.60 con 1.86 i_con 3.88 plddt 0.77 ptm 0.61 i_ptm 0.38 rg 1.91
# 128 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.65 helix 1.79 pae 0.39 i_pae 0.53 con 1.84 i_con 3.50 plddt 0.79 ptm 0.61 i_ptm 0.50 rg 1.97
# 129 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.60 helix 1.83 pae 0.39 i_pae 0.52 con 1.85 i_con 3.47 plddt 0.80 ptm 0.62 i_ptm 0.50 rg 1.92
# 130 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.85 helix 1.75 pae 0.42 i_pae 0.57 con 1.92 i_con 3.67 plddt 0.78 ptm 0.61 i_ptm 0.44 rg 1.69
# 131 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.32 helix 1.62 pae 0.55 i_pae 0.71 con 2.57 i_con 4.32 plddt 0.63 ptm 0.56 i_ptm 0.27 rg 1.86
# 132 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.29 helix 1.62 pae 0.55 i_pae 0.72 con 2.52 i_con 4.34 plddt 0.64 ptm 0.56 i_ptm 0.26 rg 1.81
# 133 models [3] recycles 1 hard 1 soft 0 temp 1 loss 6.75 helix 1.73 pae 0.54 i_pae 0.75 con 1.95 i_con 4.43 plddt 0.74 ptm 0.54 i_ptm 0.21 rg 1.76
# 134 models [3] recycles 1 hard 1 soft 0 temp 1 loss 6.82 helix 1.67 pae 0.54 i_pae 0.75 con 2.03 i_con 4.40 plddt 0.73 ptm 0.55 i_ptm 0.22 rg 1.77
# 135 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.10 helix 1.74 pae 0.55 i_pae 0.75 con 2.18 i_con 4.59 plddt 0.69 ptm 0.54 i_ptm 0.21 rg 1.63
# 136 models [2] recycles 1 hard 1 soft 0 temp 1 loss 6.96 helix 1.77 pae 0.53 i_pae 0.73 con 2.15 i_con 4.48 plddt 0.71 ptm 0.55 i_ptm 0.23 rg 1.68
# 137 models [1] recycles 1 hard 1 soft 0 temp 1 loss 6.41 helix 1.71 pae 0.47 i_pae 0.65 con 1.99 i_con 4.05 plddt 0.74 ptm 0.60 i_ptm 0.33 rg 1.88
# 138 models [2] recycles 1 hard 1 soft 0 temp 1 loss 6.57 helix 1.78 pae 0.49 i_pae 0.68 con 2.07 i_con 4.18 plddt 0.74 ptm 0.57 i_ptm 0.30 rg 1.79
# 139 models [2] recycles 1 hard 1 soft 0 temp 1 loss 7.38 helix 1.59 pae 0.55 i_pae 0.71 con 2.68 i_con 4.31 plddt 0.62 ptm 0.57 i_ptm 0.28 rg 1.70
# 140 models [1] recycles 1 hard 1 soft 0 temp 1 loss 7.58 helix 1.49 pae 0.58 i_pae 0.71 con 2.86 i_con 4.30 plddt 0.55 ptm 0.59 i_ptm 0.29 rg 1.62
# Severe clashes detected, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 11 minutes, 18 seconds
#
# Starting trajectory: PEDV_CTD_binder_l76_s449487
# Stage 1: Test Logits
# 1 models [1] recycles 1 hard 0 soft 0.02 temp 1 loss 12.56 helix 2.02 pae 0.87 i_pae 0.90 con 4.88 i_con 4.78 plddt 0.26 ptm 0.59 i_ptm 0.09 rg 9.84
# 2 models [1] recycles 1 hard 0 soft 0.04 temp 1 loss 13.64 helix 2.37 pae 0.84 i_pae 0.86 con 5.05 i_con 4.73 plddt 0.28 ptm 0.61 i_ptm 0.13 rg 13.44
# 3 models [1] recycles 1 hard 0 soft 0.05 temp 1 loss 11.68 helix 1.69 pae 0.83 i_pae 0.86 con 4.68 i_con 4.55 plddt 0.27 ptm 0.61 i_ptm 0.13 rg 8.09
# 4 models [1] recycles 1 hard 0 soft 0.07 temp 1 loss 10.64 helix 1.66 pae 0.80 i_pae 0.83 con 4.54 i_con 4.46 plddt 0.29 ptm 0.60 i_ptm 0.15 rg 5.40
# 5 models [2] recycles 1 hard 0 soft 0.09 temp 1 loss 10.01 helix 1.94 pae 0.76 i_pae 0.79 con 4.15 i_con 4.32 plddt 0.34 ptm 0.58 i_ptm 0.19 rg 5.43
# 6 models [0] recycles 1 hard 0 soft 0.11 temp 1 loss 10.32 helix 1.49 pae 0.79 i_pae 0.84 con 4.35 i_con 4.61 plddt 0.33 ptm 0.58 i_ptm 0.13 rg 4.30
# 7 models [2] recycles 1 hard 0 soft 0.13 temp 1 loss 9.46 helix 1.56 pae 0.79 i_pae 0.83 con 4.23 i_con 4.41 plddt 0.32 ptm 0.56 i_ptm 0.13 rg 2.60
# 8 models [4] recycles 1 hard 0 soft 0.14 temp 1 loss 9.40 helix 1.13 pae 0.76 i_pae 0.84 con 3.87 i_con 4.47 plddt 0.37 ptm 0.56 i_ptm 0.14 rg 3.04
# 9 models [1] recycles 1 hard 0 soft 0.16 temp 1 loss 8.99 helix 1.01 pae 0.77 i_pae 0.87 con 3.67 i_con 4.76 plddt 0.42 ptm 0.59 i_ptm 0.11 rg 1.22
# 10 models [0] recycles 1 hard 0 soft 0.18 temp 1 loss 8.52 helix 1.07 pae 0.74 i_pae 0.84 con 3.52 i_con 4.65 plddt 0.39 ptm 0.56 i_ptm 0.12 rg 0.59
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 8.58 helix 0.99 pae 0.75 i_pae 0.84 con 3.63 i_con 4.54 plddt 0.38 ptm 0.56 i_ptm 0.12 rg 0.73
# 12 models [3] recycles 1 hard 0 soft 0.22 temp 1 loss 8.57 helix 1.04 pae 0.74 i_pae 0.85 con 3.45 i_con 4.68 plddt 0.42 ptm 0.57 i_ptm 0.12 rg 0.90
# 13 models [0] recycles 1 hard 0 soft 0.23 temp 1 loss 7.99 helix 1.36 pae 0.72 i_pae 0.82 con 3.39 i_con 4.61 plddt 0.42 ptm 0.58 i_ptm 0.14 rg -0.24
# 14 models [2] recycles 1 hard 0 soft 0.25 temp 1 loss 8.61 helix 1.56 pae 0.74 i_pae 0.83 con 3.50 i_con 4.57 plddt 0.42 ptm 0.57 i_ptm 0.13 rg 1.74
# 15 models [4] recycles 1 hard 0 soft 0.27 temp 1 loss 7.82 helix 1.57 pae 0.73 i_pae 0.82 con 3.33 i_con 4.39 plddt 0.40 ptm 0.59 i_ptm 0.15 rg 0.31
# 16 models [4] recycles 1 hard 0 soft 0.29 temp 1 loss 7.24 helix 1.60 pae 0.70 i_pae 0.81 con 2.93 i_con 4.54 plddt 0.49 ptm 0.59 i_ptm 0.15 rg -0.67
# 17 models [1] recycles 1 hard 0 soft 0.31 temp 1 loss 7.76 helix 1.51 pae 0.70 i_pae 0.80 con 3.15 i_con 4.51 plddt 0.50 ptm 0.61 i_ptm 0.17 rg 0.33
# 18 models [3] recycles 1 hard 0 soft 0.32 temp 1 loss 7.45 helix 1.66 pae 0.66 i_pae 0.75 con 3.28 i_con 4.26 plddt 0.50 ptm 0.63 i_ptm 0.26 rg -0.07
# 19 models [3] recycles 1 hard 0 soft 0.34 temp 1 loss 8.10 helix 1.54 pae 0.72 i_pae 0.80 con 3.62 i_con 4.49 plddt 0.38 ptm 0.61 i_ptm 0.17 rg -0.06
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 7.28 helix 1.61 pae 0.69 i_pae 0.81 con 2.95 i_con 4.50 plddt 0.52 ptm 0.59 i_ptm 0.16 rg -0.44
# 21 models [4] recycles 1 hard 0 soft 0.38 temp 1 loss 7.99 helix 1.49 pae 0.73 i_pae 0.80 con 3.75 i_con 4.31 plddt 0.36 ptm 0.60 i_ptm 0.17 rg -0.32
# 22 models [1] recycles 1 hard 0 soft 0.40 temp 1 loss 8.47 helix 1.78 pae 0.76 i_pae 0.82 con 3.73 i_con 4.46 plddt 0.37 ptm 0.61 i_ptm 0.16 rg 1.10
# 23 models [0] recycles 1 hard 0 soft 0.41 temp 1 loss 7.08 helix 1.95 pae 0.69 i_pae 0.83 con 2.62 i_con 4.73 plddt 0.57 ptm 0.59 i_ptm 0.15 rg -0.46
# 24 models [4] recycles 1 hard 0 soft 0.43 temp 1 loss 6.81 helix 2.02 pae 0.69 i_pae 0.83 con 2.56 i_con 4.53 plddt 0.57 ptm 0.57 i_ptm 0.13 rg -0.42
# 25 models [0] recycles 1 hard 0 soft 0.45 temp 1 loss 7.05 helix 2.13 pae 0.69 i_pae 0.83 con 2.56 i_con 4.70 plddt 0.56 ptm 0.57 i_ptm 0.15 rg -0.05
# 26 models [3] recycles 1 hard 0 soft 0.47 temp 1 loss 6.69 helix 2.22 pae 0.67 i_pae 0.81 con 2.44 i_con 4.59 plddt 0.61 ptm 0.59 i_ptm 0.14 rg -0.35
# 27 models [4] recycles 1 hard 0 soft 0.49 temp 1 loss 7.18 helix 1.97 pae 0.70 i_pae 0.79 con 3.22 i_con 4.28 plddt 0.41 ptm 0.60 i_ptm 0.18 rg -0.62
# 28 models [3] recycles 1 hard 0 soft 0.50 temp 1 loss 7.96 helix 1.82 pae 0.73 i_pae 0.81 con 3.47 i_con 4.53 plddt 0.39 ptm 0.60 i_ptm 0.16 rg 0.08
# 29 models [4] recycles 1 hard 0 soft 0.52 temp 1 loss 6.45 helix 2.34 pae 0.67 i_pae 0.82 con 2.27 i_con 4.58 plddt 0.65 ptm 0.58 i_ptm 0.15 rg -0.41
# 30 models [1] recycles 1 hard 0 soft 0.54 temp 1 loss 7.97 helix 1.85 pae 0.74 i_pae 0.83 con 3.42 i_con 4.56 plddt 0.40 ptm 0.60 i_ptm 0.14 rg 0.18
# 31 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 6.72 helix 2.25 pae 0.69 i_pae 0.83 con 2.45 i_con 4.66 plddt 0.60 ptm 0.54 i_ptm 0.14 rg -0.52
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 6.20 helix 2.32 pae 0.64 i_pae 0.80 con 2.17 i_con 4.44 plddt 0.66 ptm 0.59 i_ptm 0.16 rg -0.44
# 33 models [4] recycles 1 hard 0 soft 0.59 temp 1 loss 6.08 helix 2.48 pae 0.64 i_pae 0.80 con 2.01 i_con 4.50 plddt 0.69 ptm 0.58 i_ptm 0.16 rg -0.32
# 34 models [2] recycles 1 hard 0 soft 0.61 temp 1 loss 5.80 helix 2.59 pae 0.61 i_pae 0.78 con 1.96 i_con 4.31 plddt 0.74 ptm 0.56 i_ptm 0.17 rg -0.26
# 35 models [2] recycles 1 hard 0 soft 0.63 temp 1 loss 6.01 helix 2.48 pae 0.64 i_pae 0.78 con 2.05 i_con 4.40 plddt 0.68 ptm 0.56 i_ptm 0.19 rg -0.33
# 36 models [1] recycles 1 hard 0 soft 0.65 temp 1 loss 6.07 helix 2.41 pae 0.58 i_pae 0.74 con 2.07 i_con 4.44 plddt 0.73 ptm 0.61 i_ptm 0.20 rg -0.28
# 37 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 6.32 helix 2.23 pae 0.63 i_pae 0.76 con 2.36 i_con 4.31 plddt 0.59 ptm 0.61 i_ptm 0.21 rg -0.31
# 38 models [4] recycles 1 hard 0 soft 0.68 temp 1 loss 6.84 helix 2.07 pae 0.67 i_pae 0.79 con 2.75 i_con 4.37 plddt 0.52 ptm 0.60 i_ptm 0.18 rg -0.34

# %%
#@title Consolidate & Rank Designs
#@markdown ---
accepted_binders = [f for f in os.listdir(design_paths["Accepted"]) if f.endswith('.pdb')]

for f in os.listdir(design_paths["Accepted/Ranked"]):
    os.remove(os.path.join(design_paths["Accepted/Ranked"], f))

# load dataframe of designed binders
design_df = pd.read_csv(mpnn_csv)
design_df = design_df.sort_values('Average_i_pTM', ascending=False)

# create final csv dataframe to copy matched rows, initialize with the column labels
final_df = pd.DataFrame(columns=final_labels)

# check the ranking of the designs and copy them with new ranked IDs to the folder
rank = 1
for _, row in design_df.iterrows():
    for binder in accepted_binders:
        target_settings["binder_name"], model = binder.rsplit('_model', 1)
        if target_settings["binder_name"] == row['Design']:
            # rank and copy into ranked folder
            row_data = {'Rank': rank, **{label: row[label] for label in design_labels}}
            final_df = pd.concat([final_df, pd.DataFrame([row_data])], ignore_index=True)
            old_path = os.path.join(design_paths["Accepted"], binder)
            new_path = os.path.join(design_paths["Accepted/Ranked"], f"{rank}_{target_settings['binder_name']}_model{model.rsplit('.', 1)[0]}.pdb")
            shutil.copyfile(old_path, new_path)

            rank += 1
            break

# save the final_df to final_csv
final_df.to_csv(final_csv, index=False)

print("Designs ranked and final_designs_stats.csv generated")

# %%
#@title Top 20 Designs
df = pd.read_csv(os.path.join(design_path, 'final_design_stats.csv'))
df.head(20)

# %%
#@title Top Design Display
import py3Dmol
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

# Visualise in PyMOL
view = py3Dmol.view()
view.addModel(open(top_design_pdb, 'r').read(),'pdb')
view.setBackgroundColor('white')
view.setStyle({'chain':'A'}, {'cartoon': {'color':'#3c5b6f'}})
view.setStyle({'chain':'B'}, {'cartoon': {'color':'#B76E79'}})
view.zoomTo()
view.show()

# %%
#@title Display animation
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

top_design_name = os.path.basename(top_design_pdb).split('1_', 1)[1].split('_mpnn')[0]
top_design_animation = os.path.join(design_path, 'Accepted', 'Animation', f"{top_design_name}.html")

# Show animation
HTML(top_design_animation)
